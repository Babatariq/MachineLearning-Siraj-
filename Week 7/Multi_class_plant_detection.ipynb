# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# We will start with bringing in Modules for this Numpy only implementation of a classifier

# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2
import glob

# %matplotlib inline
#plt.rcParams['figure.figsize'] = (19.0, 17.0) # set default size of plots
#plt.rcParams['figure.figsize'] = (13.0, 11.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (3.0.6)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.9.11)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)

# %%
# !mkdir .kaggle

# %%
token = {"username":"babatariq","key":"bb26bd811560e2ae125aeda707adaeb8"} 

with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !kaggle datasets download -d fpeccia/weed-detection-in-soybean-crops
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading weed-detection-in-soybean-crops.zip to /content
# 100% 2.37G/2.37G [01:04<00:00, 54.4MB/s]

# %%
print(os.listdir())
# Out:
# ['.config', '.kaggle', 'weed-detection-in-soybean-crops.zip', 'drive', 'sample_data']

# %%
# !unzip -q weed-detection-in-soybean-crops.zip
# Out:
# replace dataset/broadleaf/1.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dataset/broadleaf/10.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dataset/broadleaf/100.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dataset/broadleaf/1000.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dataset/broadleaf/1001.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dataset/broadleaf/1002.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dataset/broadleaf/1003.tif? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
print(os.listdir())
# Out:
# ['.config', '.kaggle', 'weed-detection-in-soybean-crops.zip', 'drive', 'dataset', 'sample_data']

# %% [markdown]
# Here we will make a trick by rotating and flipping images to create "New" data to train on using the downloaded data set

# %%
class Data_augmentation:
    def __init__(self, path, image_name):
        '''
        Import image
        :param path: Path to the image
        :param image_name: image name
        '''
        self.path = path
        self.name = image_name
        print(path+image_name)
        self.image = cv2.imread(path+image_name)

    def rotate(self, image, angle=90, scale=1.0):
        '''
        Rotate the image
        :param image: image to be processed
        :param angle: Rotation angle in degrees. Positive values mean counter-clockwise rotation (the coordinate origin is assumed to be the top-left corner).
        :param scale: Isotropic scale factor.
        '''
        w = image.shape[1]
        h = image.shape[0]
        #rotate matrix
        M = cv2.getRotationMatrix2D((w/2,h/2), angle, scale)
        #rotate
        image = cv2.warpAffine(image,M,(w,h))
        return image

    def flip(self, image, vflip=False, hflip=False):
        '''
        Flip the image
        :param image: image to be processed
        :param vflip: whether to flip the image vertically
        :param hflip: whether to flip the image horizontally
        '''
        if hflip or vflip:
            if hflip and vflip:
                c = -1
            else:
                c = 0 if vflip else 1
            image = cv2.flip(image, flipCode=c)
        return image 
    
    
    def image_augment(self, save_path): 
        '''
        Create the new image with imge augmentation
        
        ''' 
        img = self.image.copy()
        img_flip = self.flip(img, vflip=True, hflip=False)
        img_rot = self.rotate(img)
        #img_gaussian = self.add_GaussianNoise(img)
        
        name_int = self.name[:len(self.name)-4]
        cv2.imwrite(save_path+'%s' %str(name_int)+'_vflip.jpg', img_flip)
        cv2.imwrite(save_path+'%s' %str(name_int)+'_rot.jpg', img_rot)
        #cv2.imwrite(save_path+'%s' %str(name_int)+'_GaussianNoise.jpg', img_gaussian)

# %%
def main(file_dir,output_path):
        for root, _, files in os.walk(file_dir):
            print(root)
        for file in files:
            raw_image = Data_augmentation(root,file)
            raw_image.image_augment(output_path)

# %%
file_dir = 'dataset/dataset/broadleaf/'
output_path = './dataset/broadleaf/'
main(file_dir=file_dir, output_path=output_path)

file_dir = 'dataset/dataset/grass/'
output_path = './dataset/grass/'
main(file_dir=file_dir, output_path=output_path)

file_dir = 'dataset/dataset/soil/'
output_path = 'dataset/soil/'
main(file_dir=file_dir, output_path=output_path)

file_dir = 'dataset/dataset/soybean/'
output_path = './dataset/soybean/'
main(file_dir=file_dir, output_path=output_path)
# Out:
# dataset/dataset/broadleaf/
# dataset/dataset/broadleaf/660.tif
# dataset/dataset/broadleaf/613.tif
# dataset/dataset/broadleaf/540.tif
# dataset/dataset/broadleaf/83.tif
# dataset/dataset/broadleaf/587.tif
# dataset/dataset/broadleaf/733.tif
# dataset/dataset/broadleaf/123.tif
# dataset/dataset/broadleaf/817.tif
# dataset/dataset/broadleaf/169.tif
# dataset/dataset/broadleaf/287.tif
# dataset/dataset/broadleaf/142.tif
# dataset/dataset/broadleaf/452.tif
# dataset/dataset/broadleaf/1141.tif
# dataset/dataset/broadleaf/236.tif
# dataset/dataset/broadleaf/571.tif
# dataset/dataset/broadleaf/756.tif
# dataset/dataset/broadleaf/1008.tif
# dataset/dataset/broadleaf/1043.tif
# dataset/dataset/broadleaf/531.tif
# dataset/dataset/broadleaf/314.tif
# dataset/dataset/broadleaf/1159.tif
# dataset/dataset/broadleaf/1165.tif
# dataset/dataset/broadleaf/1111.tif
# dataset/dataset/broadleaf/137.tif
# dataset/dataset/broadleaf/622.tif
# dataset/dataset/broadleaf/192.tif
# dataset/dataset/broadleaf/641.tif
# dataset/dataset/broadleaf/1074.tif
# dataset/dataset/broadleaf/368.tif
# dataset/dataset/broadleaf/700.tif
# dataset/dataset/broadleaf/884.tif
# dataset/dataset/broadleaf/870.tif
# dataset/dataset/broadleaf/390.tif
# dataset/dataset/broadleaf/482.tif
# dataset/dataset/broadleaf/624.tif
# dataset/dataset/broadleaf/1161.tif
# dataset/dataset/broadleaf/596.tif
# dataset/dataset/broadleaf/115.tif
# dataset/dataset/broadleaf/440.tif
# dataset/dataset/broadleaf/419.tif
# dataset/dataset/broadleaf/909.tif
# dataset/dataset/broadleaf/957.tif
# dataset/dataset/broadleaf/144.tif
# dataset/dataset/broadleaf/777.tif
# dataset/dataset/broadleaf/446.tif
# dataset/dataset/broadleaf/152.tif
# dataset/dataset/broadleaf/695.tif
# dataset/dataset/broadleaf/557.tif
# dataset/dataset/broadleaf/1065.tif
# dataset/dataset/broadleaf/989.tif
# dataset/dataset/broadleaf/343.tif
# dataset/dataset/broadleaf/498.tif
# dataset/dataset/broadleaf/943.tif
# dataset/dataset/broadleaf/484.tif
# dataset/dataset/broadleaf/296.tif
# dataset/dataset/broadleaf/732.tif
# dataset/dataset/broadleaf/39.tif
# dataset/dataset/broadleaf/573.tif
# dataset/dataset/broadleaf/815.tif
# dataset/dataset/broadleaf/680.tif
# dataset/dataset/broadleaf/577.tif
# dataset/dataset/broadleaf/198.tif
# dataset/dataset/broadleaf/952.tif
# dataset/dataset/broadleaf/768.tif
# dataset/dataset/broadleaf/76.tif
# dataset/dataset/broadleaf/1169.tif
# dataset/dataset/broadleaf/414.tif
# dataset/dataset/broadleaf/253.tif
# dataset/dataset/broadleaf/453.tif
# dataset/dataset/broadleaf/478.tif
# dataset/dataset/broadleaf/1044.tif
# dataset/dataset/broadleaf/342.tif
# dataset/dataset/broadleaf/770.tif
# dataset/dataset/broadleaf/292.tif
# dataset/dataset/broadleaf/492.tif
# dataset/dataset/broadleaf/483.tif
# dataset/dataset/broadleaf/5.tif
# dataset/dataset/broadleaf/348.tif
# dataset/dataset/broadleaf/669.tif
# dataset/dataset/broadleaf/523.tif
# dataset/dataset/broadleaf/451.tif
# dataset/dataset/broadleaf/378.tif
# dataset/dataset/broadleaf/1012.tif
# dataset/dataset/broadleaf/998.tif
# dataset/dataset/broadleaf/752.tif
# dataset/dataset/broadleaf/942.tif
# dataset/dataset/broadleaf/534.tif
# dataset/dataset/broadleaf/439.tif
# dataset/dataset/broadleaf/771.tif
# dataset/dataset/broadleaf/1088.tif
# dataset/dataset/broadleaf/758.tif
# dataset/dataset/broadleaf/591.tif
# dataset/dataset/broadleaf/277.tif
# dataset/dataset/broadleaf/956.tif
# dataset/dataset/broadleaf/707.tif
# dataset/dataset/broadleaf/806.tif
# dataset/dataset/broadleaf/243.tif
# dataset/dataset/broadleaf/538.tif
# dataset/dataset/broadleaf/329.tif
# dataset/dataset/broadleaf/1188.tif
# dataset/dataset/broadleaf/658.tif
# dataset/dataset/broadleaf/584.tif
# dataset/dataset/broadleaf/868.tif
# dataset/dataset/broadleaf/509.tif
# dataset/dataset/broadleaf/297.tif
# dataset/dataset/broadleaf/542.tif
# dataset/dataset/broadleaf/588.tif
# dataset/dataset/broadleaf/41.tif
# dataset/dataset/broadleaf/84.tif
# dataset/dataset/broadleaf/230.tif
# dataset/dataset/broadleaf/1036.tif
# dataset/dataset/broadleaf/631.tif
# dataset/dataset/broadleaf/448.tif
# dataset/dataset/broadleaf/256.tif
# dataset/dataset/broadleaf/500.tif
# dataset/dataset/broadleaf/62.tif
# dataset/dataset/broadleaf/691.tif
# dataset/dataset/broadleaf/245.tif
# dataset/dataset/broadleaf/569.tif
# dataset/dataset/broadleaf/474.tif
# dataset/dataset/broadleaf/372.tif
# dataset/dataset/broadleaf/1182.tif
# dataset/dataset/broadleaf/524.tif
# dataset/dataset/broadleaf/885.tif
# dataset/dataset/broadleaf/618.tif
# dataset/dataset/broadleaf/975.tif
# dataset/dataset/broadleaf/352.tif
# dataset/dataset/broadleaf/525.tif
# dataset/dataset/broadleaf/321.tif
# dataset/dataset/broadleaf/22.tif
# dataset/dataset/broadleaf/400.tif
# dataset/dataset/broadleaf/1160.tif
# dataset/dataset/broadleaf/738.tif
# dataset/dataset/broadleaf/1058.tif
# dataset/dataset/broadleaf/747.tif
# dataset/dataset/broadleaf/563.tif
# dataset/dataset/broadleaf/1064.tif
# dataset/dataset/broadleaf/413.tif
# dataset/dataset/broadleaf/634.tif
# dataset/dataset/broadleaf/274.tif
# dataset/dataset/broadleaf/969.tif
# dataset/dataset/broadleaf/279.tif
# dataset/dataset/broadleaf/220.tif
# dataset/dataset/broadleaf/599.tif
# dataset/dataset/broadleaf/1172.tif
# dataset/dataset/broadleaf/820.tif
# dataset/dataset/broadleaf/773.tif
# dataset/dataset/broadleaf/1090.tif
# dataset/dataset/broadleaf/180.tif
# dataset/dataset/broadleaf/598.tif
# dataset/dataset/broadleaf/374.tif
# dataset/dataset/broadleaf/399.tif
# dataset/dataset/broadleaf/562.tif
# dataset/dataset/broadleaf/939.tif
# dataset/dataset/broadleaf/218.tif
# dataset/dataset/broadleaf/370.tif
# dataset/dataset/broadleaf/10.tif
# dataset/dataset/broadleaf/437.tif
# dataset/dataset/broadleaf/1178.tif
# dataset/dataset/broadleaf/657.tif
# dataset/dataset/broadleaf/986.tif
# dataset/dataset/broadleaf/325.tif
# dataset/dataset/broadleaf/310.tif
# dataset/dataset/broadleaf/537.tif
# dataset/dataset/broadleaf/301.tif
# dataset/dataset/broadleaf/904.tif
# dataset/dataset/broadleaf/689.tif
# dataset/dataset/broadleaf/627.tif
# dataset/dataset/broadleaf/95.tif
# dataset/dataset/broadleaf/2.tif
# dataset/dataset/broadleaf/1142.tif
# dataset/dataset/broadleaf/1092.tif
# dataset/dataset/broadleaf/486.tif
# dataset/dataset/broadleaf/367.tif
# dataset/dataset/broadleaf/465.tif
# dataset/dataset/broadleaf/929.tif
# dataset/dataset/broadleaf/252.tif
# dataset/dataset/broadleaf/58.tif
# dataset/dataset/broadleaf/31.tif
# dataset/dataset/broadleaf/163.tif
# dataset/dataset/broadleaf/1094.tif
# dataset/dataset/broadleaf/692.tif
# dataset/dataset/broadleaf/1190.tif
# dataset/dataset/broadleaf/94.tif
# dataset/dataset/broadleaf/853.tif
# dataset/dataset/broadleaf/307.tif
# dataset/dataset/broadleaf/914.tif
# dataset/dataset/broadleaf/1151.tif
# dataset/dataset/broadleaf/109.tif
# dataset/dataset/broadleaf/315.tif
# dataset/dataset/broadleaf/920.tif
# dataset/dataset/broadleaf/146.tif
# dataset/dataset/broadleaf/869.tif
# dataset/dataset/broadleaf/316.tif
# dataset/dataset/broadleaf/444.tif
# dataset/dataset/broadleaf/980.tif
# dataset/dataset/broadleaf/572.tif
# dataset/dataset/broadleaf/737.tif
# dataset/dataset/broadleaf/614.tif
# dataset/dataset/broadleaf/1157.tif
# dataset/dataset/broadleaf/214.tif
# dataset/dataset/broadleaf/194.tif
# dataset/dataset/broadleaf/722.tif
# dataset/dataset/broadleaf/145.tif
# dataset/dataset/broadleaf/710.tif
# dataset/dataset/broadleaf/1164.tif
# dataset/dataset/broadleaf/470.tif
# dataset/dataset/broadleaf/24.tif
# dataset/dataset/broadleaf/337.tif
# dataset/dataset/broadleaf/332.tif
# dataset/dataset/broadleaf/304.tif
# dataset/dataset/broadleaf/276.tif
# dataset/dataset/broadleaf/823.tif
# dataset/dataset/broadleaf/719.tif
# dataset/dataset/broadleaf/17.tif
# dataset/dataset/broadleaf/536.tif
# dataset/dataset/broadleaf/433.tif
# dataset/dataset/broadleaf/88.tif
# dataset/dataset/broadleaf/611.tif
# dataset/dataset/broadleaf/1186.tif
# dataset/dataset/broadleaf/899.tif
# dataset/dataset/broadleaf/607.tif
# dataset/dataset/broadleaf/1137.tif
# dataset/dataset/broadleaf/129.tif
# dataset/dataset/broadleaf/965.tif
# dataset/dataset/broadleaf/60.tif
# dataset/dataset/broadleaf/134.tif
# dataset/dataset/broadleaf/675.tif
# dataset/dataset/broadleaf/265.tif
# dataset/dataset/broadleaf/992.tif
# dataset/dataset/broadleaf/981.tif
# dataset/dataset/broadleaf/86.tif
# dataset/dataset/broadleaf/293.tif
# dataset/dataset/broadleaf/327.tif
# dataset/dataset/broadleaf/1011.tif
# dataset/dataset/broadleaf/1120.tif
# dataset/dataset/broadleaf/1073.tif
# dataset/dataset/broadleaf/204.tif
# dataset/dataset/broadleaf/503.tif
# dataset/dataset/broadleaf/1153.tif
# dataset/dataset/broadleaf/724.tif
# dataset/dataset/broadleaf/794.tif
# dataset/dataset/broadleaf/725.tif
# dataset/dataset/broadleaf/964.tif
# dataset/dataset/broadleaf/925.tif
# dataset/dataset/broadleaf/1180.tif
# dataset/dataset/broadleaf/686.tif
# dataset/dataset/broadleaf/298.tif
# dataset/dataset/broadleaf/1115.tif
# dataset/dataset/broadleaf/793.tif
# dataset/dataset/broadleaf/1152.tif
# dataset/dataset/broadleaf/408.tif
# dataset/dataset/broadleaf/1033.tif
# dataset/dataset/broadleaf/1002.tif
# dataset/dataset/broadleaf/541.tif
# dataset/dataset/broadleaf/889.tif
# dataset/dataset/broadleaf/249.tif
# dataset/dataset/broadleaf/257.tif
# dataset/dataset/broadleaf/1016.tif
# dataset/dataset/broadleaf/447.tif
# dataset/dataset/broadleaf/197.tif
# dataset/dataset/broadleaf/113.tif
# dataset/dataset/broadleaf/1046.tif
# dataset/dataset/broadleaf/788.tif
# dataset/dataset/broadleaf/1106.tif
# dataset/dataset/broadleaf/626.tif
# dataset/dataset/broadleaf/365.tif
# dataset/dataset/broadleaf/216.tif
# dataset/dataset/broadleaf/1052.tif
# dataset/dataset/broadleaf/813.tif
# dataset/dataset/broadleaf/396.tif
# dataset/dataset/broadleaf/539.tif
# dataset/dataset/broadleaf/487.tif
# dataset/dataset/broadleaf/359.tif
# dataset/dataset/broadleaf/104.tif
# dataset/dataset/broadleaf/425.tif
# dataset/dataset/broadleaf/11.tif
# dataset/dataset/broadleaf/895.tif
# dataset/dataset/broadleaf/320.tif
# dataset/dataset/broadleaf/638.tif
# dataset/dataset/broadleaf/135.tif
# dataset/dataset/broadleaf/312.tif
# dataset/dataset/broadleaf/1015.tif
# dataset/dataset/broadleaf/476.tif
# dataset/dataset/broadleaf/271.tif
# dataset/dataset/broadleaf/739.tif
# dataset/dataset/broadleaf/802.tif
# dataset/dataset/broadleaf/1082.tif
# dataset/dataset/broadleaf/864.tif
# dataset/dataset/broadleaf/435.tif
# dataset/dataset/broadleaf/138.tif
# dataset/dataset/broadleaf/57.tif
# dataset/dataset/broadleaf/553.tif
# dataset/dataset/broadleaf/714.tif
# dataset/dataset/broadleaf/226.tif
# dataset/dataset/broadleaf/195.tif
# dataset/dataset/broadleaf/673.tif
# dataset/dataset/broadleaf/201.tif
# dataset/dataset/broadleaf/505.tif
# dataset/dataset/broadleaf/1154.tif
# dataset/dataset/broadleaf/411.tif
# dataset/dataset/broadleaf/972.tif
# dataset/dataset/broadleaf/78.tif
# dataset/dataset/broadleaf/464.tif
# dataset/dataset/broadleaf/833.tif
# dataset/dataset/broadleaf/251.tif
# dataset/dataset/broadleaf/151.tif
# dataset/dataset/broadleaf/782.tif
# dataset/dataset/broadleaf/535.tif
# dataset/dataset/broadleaf/384.tif
# dataset/dataset/broadleaf/1131.tif
# dataset/dataset/broadleaf/375.tif
# dataset/dataset/broadleaf/28.tif
# dataset/dataset/broadleaf/944.tif
# dataset/dataset/broadleaf/880.tif
# dataset/dataset/broadleaf/289.tif
# dataset/dataset/broadleaf/385.tif
# dataset/dataset/broadleaf/215.tif
# dataset/dataset/broadleaf/97.tif
# dataset/dataset/broadleaf/630.tif
# dataset/dataset/broadleaf/131.tif
# dataset/dataset/broadleaf/560.tif
# dataset/dataset/broadleaf/309.tif
# dataset/dataset/broadleaf/761.tif
# dataset/dataset/broadleaf/344.tif
# dataset/dataset/broadleaf/988.tif
# dataset/dataset/broadleaf/837.tif
# dataset/dataset/broadleaf/945.tif
# dataset/dataset/broadleaf/406.tif
# dataset/dataset/broadleaf/431.tif
# dataset/dataset/broadleaf/377.tif
# dataset/dataset/broadleaf/1031.tif
# dataset/dataset/broadleaf/958.tif
# dataset/dataset/broadleaf/1041.tif
# dataset/dataset/broadleaf/222.tif
# dataset/dataset/broadleaf/663.tif
# dataset/dataset/broadleaf/479.tif
# dataset/dataset/broadleaf/1022.tif
# dataset/dataset/broadleaf/760.tif
# dataset/dataset/broadleaf/900.tif
# dataset/dataset/broadleaf/860.tif
# dataset/dataset/broadleaf/90.tif
# dataset/dataset/broadleaf/450.tif
# dataset/dataset/broadleaf/111.tif
# dataset/dataset/broadleaf/1101.tif
# dataset/dataset/broadleaf/1139.tif
# dataset/dataset/broadleaf/694.tif
# dataset/dataset/broadleaf/8.tif
# dataset/dataset/broadleaf/20.tif
# dataset/dataset/broadleaf/814.tif
# dataset/dataset/broadleaf/467.tif
# dataset/dataset/broadleaf/843.tif
# dataset/dataset/broadleaf/612.tif
# dataset/dataset/broadleaf/863.tif
# dataset/dataset/broadleaf/71.tif
# dataset/dataset/broadleaf/1158.tif
# dataset/dataset/broadleaf/1007.tif
# dataset/dataset/broadleaf/116.tif
# dataset/dataset/broadleaf/499.tif
# dataset/dataset/broadleaf/757.tif
# dataset/dataset/broadleaf/633.tif
# dataset/dataset/broadleaf/50.tif
# dataset/dataset/broadleaf/735.tif
# dataset/dataset/broadleaf/188.tif
# dataset/dataset/broadleaf/543.tif
# dataset/dataset/broadleaf/1030.tif
# dataset/dataset/broadleaf/850.tif
# dataset/dataset/broadleaf/567.tif
# dataset/dataset/broadleaf/306.tif
# dataset/dataset/broadleaf/26.tif
# dataset/dataset/broadleaf/472.tif
# dataset/dataset/broadleaf/570.tif
# dataset/dataset/broadleaf/953.tif
# dataset/dataset/broadleaf/70.tif
# dataset/dataset/broadleaf/1189.tif
# dataset/dataset/broadleaf/449.tif
# dataset/dataset/broadleaf/504.tif
# dataset/dataset/broadleaf/1109.tif
# dataset/dataset/broadleaf/170.tif
# dataset/dataset/broadleaf/421.tif
# dataset/dataset/broadleaf/589.tif
# dataset/dataset/broadleaf/259.tif
# dataset/dataset/broadleaf/207.tif
# dataset/dataset/broadleaf/871.tif
# dataset/dataset/broadleaf/787.tif
# dataset/dataset/broadleaf/698.tif
# dataset/dataset/broadleaf/519.tif
# dataset/dataset/broadleaf/911.tif
# dataset/dataset/broadleaf/423.tif
# dataset/dataset/broadleaf/705.tif
# dataset/dataset/broadleaf/353.tif
# dataset/dataset/broadleaf/345.tif
# dataset/dataset/broadleaf/874.tif
# dataset/dataset/broadleaf/397.tif
# dataset/dataset/broadleaf/1029.tif
# dataset/dataset/broadleaf/9.tif
# dataset/dataset/broadleaf/410.tif
# dataset/dataset/broadleaf/610.tif
# dataset/dataset/broadleaf/196.tif
# dataset/dataset/broadleaf/1116.tif
# dataset/dataset/broadleaf/13.tif
# dataset/dataset/broadleaf/527.tif
# dataset/dataset/broadleaf/1136.tif
# dataset/dataset/broadleaf/261.tif
# dataset/dataset/broadleaf/502.tif
# dataset/dataset/broadleaf/935.tif
# dataset/dataset/broadleaf/905.tif
# dataset/dataset/broadleaf/205.tif
# dataset/dataset/broadleaf/824.tif
# dataset/dataset/broadleaf/915.tif
# dataset/dataset/broadleaf/48.tif
# dataset/dataset/broadleaf/784.tif
# dataset/dataset/broadleaf/642.tif
# dataset/dataset/broadleaf/355.tif
# dataset/dataset/broadleaf/984.tif
# dataset/dataset/broadleaf/916.tif
# dataset/dataset/broadleaf/1117.tif
# dataset/dataset/broadleaf/829.tif
# dataset/dataset/broadleaf/1010.tif
# dataset/dataset/broadleaf/150.tif
# dataset/dataset/broadleaf/1050.tif
# dataset/dataset/broadleaf/962.tif
# dataset/dataset/broadleaf/460.tif
# dataset/dataset/broadleaf/158.tif
# dataset/dataset/broadleaf/182.tif
# dataset/dataset/broadleaf/67.tif
# dataset/dataset/broadleaf/744.tif
# dataset/dataset/broadleaf/270.tif
# dataset/dataset/broadleaf/1155.tif
# dataset/dataset/broadleaf/1023.tif
# dataset/dataset/broadleaf/936.tif
# dataset/dataset/broadleaf/3.tif
# dataset/dataset/broadleaf/848.tif
# dataset/dataset/broadleaf/442.tif
# dataset/dataset/broadleaf/581.tif
# dataset/dataset/broadleaf/545.tif
# dataset/dataset/broadleaf/759.tif
# dataset/dataset/broadleaf/1083.tif
# dataset/dataset/broadleaf/356.tif
# dataset/dataset/broadleaf/438.tif
# dataset/dataset/broadleaf/300.tif
# dataset/dataset/broadleaf/73.tif
# dataset/dataset/broadleaf/295.tif
# dataset/dataset/broadleaf/148.tif
# dataset/dataset/broadleaf/1140.tif
# dataset/dataset/broadleaf/1026.tif
# dataset/dataset/broadleaf/340.tif
# dataset/dataset/broadleaf/404.tif
# dataset/dataset/broadleaf/1034.tif
# dataset/dataset/broadleaf/990.tif
# dataset/dataset/broadleaf/45.tif
# dataset/dataset/broadleaf/278.tif
# dataset/dataset/broadleaf/861.tif
# dataset/dataset/broadleaf/983.tif
# dataset/dataset/broadleaf/1132.tif
# dataset/dataset/broadleaf/564.tif
# dataset/dataset/broadleaf/1025.tif
# dataset/dataset/broadleaf/937.tif
# dataset/dataset/broadleaf/268.tif
# dataset/dataset/broadleaf/1163.tif
# dataset/dataset/broadleaf/804.tif
# dataset/dataset/broadleaf/1128.tif
# dataset/dataset/broadleaf/821.tif
# dataset/dataset/broadleaf/728.tif
# dataset/dataset/broadleaf/947.tif
# dataset/dataset/broadleaf/865.tif
# dataset/dataset/broadleaf/715.tif
# dataset/dataset/broadleaf/237.tif
# dataset/dataset/broadleaf/494.tif
# dataset/dataset/broadleaf/604.tif
# dataset/dataset/broadleaf/224.tif
# dataset/dataset/broadleaf/934.tif
# dataset/dataset/broadleaf/1019.tif
# dataset/dataset/broadleaf/819.tif
# dataset/dataset/broadleaf/1057.tif
# dataset/dataset/broadleaf/931.tif
# dataset/dataset/broadleaf/574.tif
# dataset/dataset/broadleaf/92.tif
# dataset/dataset/broadleaf/836.tif
# dataset/dataset/broadleaf/193.tif
# dataset/dataset/broadleaf/803.tif
# dataset/dataset/broadleaf/99.tif
# dataset/dataset/broadleaf/512.tif
# dataset/dataset/broadleaf/966.tif
# dataset/dataset/broadleaf/47.tif
# dataset/dataset/broadleaf/890.tif
# dataset/dataset/broadleaf/105.tif
# dataset/dataset/broadleaf/235.tif
# dataset/dataset/broadleaf/608.tif
# dataset/dataset/broadleaf/1072.tif
# dataset/dataset/broadleaf/951.tif
# dataset/dataset/broadleaf/1032.tif
# dataset/dataset/broadleaf/1150.tif
# dataset/dataset/broadleaf/202.tif
# dataset/dataset/broadleaf/623.tif
# dataset/dataset/broadleaf/996.tif
# dataset/dataset/broadleaf/14.tif
# dataset/dataset/broadleaf/1183.tif
# dataset/dataset/broadleaf/19.tif
# dataset/dataset/broadleaf/333.tif
# dataset/dataset/broadleaf/208.tif
# dataset/dataset/broadleaf/780.tif
# dataset/dataset/broadleaf/457.tif
# dataset/dataset/broadleaf/61.tif
# dataset/dataset/broadleaf/1167.tif
# dataset/dataset/broadleaf/357.tif
# dataset/dataset/broadleaf/65.tif
# dataset/dataset/broadleaf/42.tif
# dataset/dataset/broadleaf/210.tif
# dataset/dataset/broadleaf/100.tif
# dataset/dataset/broadleaf/181.tif
# dataset/dataset/broadleaf/156.tif
# dataset/dataset/broadleaf/917.tif
# dataset/dataset/broadleaf/331.tif
# dataset/dataset/broadleaf/712.tif
# dataset/dataset/broadleaf/662.tif
# dataset/dataset/broadleaf/575.tif
# dataset/dataset/broadleaf/593.tif
# dataset/dataset/broadleaf/72.tif
# dataset/dataset/broadleaf/272.tif
# dataset/dataset/broadleaf/118.tif
# dataset/dataset/broadleaf/258.tif
# dataset/dataset/broadleaf/429.tif
# dataset/dataset/broadleaf/351.tif
# dataset/dataset/broadleaf/350.tif
# dataset/dataset/broadleaf/798.tif
# dataset/dataset/broadleaf/854.tif
# dataset/dataset/broadleaf/940.tif
# dataset/dataset/broadleaf/764.tif
# dataset/dataset/broadleaf/283.tif
# dataset/dataset/broadleaf/792.tif
# dataset/dataset/broadleaf/445.tif
# dataset/dataset/broadleaf/93.tif
# dataset/dataset/broadleaf/103.tif
# dataset/dataset/broadleaf/974.tif
# dataset/dataset/broadleaf/221.tif
# dataset/dataset/broadleaf/1039.tif
# dataset/dataset/broadleaf/282.tif
# dataset/dataset/broadleaf/79.tif
# dataset/dataset/broadleaf/489.tif
# dataset/dataset/broadleaf/229.tif
# dataset/dataset/broadleaf/867.tif
# dataset/dataset/broadleaf/1047.tif
# dataset/dataset/broadleaf/82.tif
# dataset/dataset/broadleaf/1177.tif
# dataset/dataset/broadleaf/959.tif
# dataset/dataset/broadleaf/319.tif
# dataset/dataset/broadleaf/231.tif
# dataset/dataset/broadleaf/1018.tif
# dataset/dataset/broadleaf/393.tif
# dataset/dataset/broadleaf/1062.tif
# dataset/dataset/broadleaf/1105.tif
# dataset/dataset/broadleaf/808.tif
# dataset/dataset/broadleaf/219.tif
# dataset/dataset/broadleaf/508.tif
# dataset/dataset/broadleaf/776.tif
# dataset/dataset/broadleaf/317.tif
# dataset/dataset/broadleaf/168.tif
# dataset/dataset/broadleaf/16.tif
# dataset/dataset/broadleaf/881.tif
# dataset/dataset/broadleaf/982.tif
# dataset/dataset/broadleaf/517.tif
# dataset/dataset/broadleaf/907.tif
# dataset/dataset/broadleaf/66.tif
# dataset/dataset/broadleaf/364.tif
# dataset/dataset/broadleaf/654.tif
# dataset/dataset/broadleaf/1184.tif
# dataset/dataset/broadleaf/646.tif
# dataset/dataset/broadleaf/639.tif
# dataset/dataset/broadleaf/239.tif
# dataset/dataset/broadleaf/644.tif
# dataset/dataset/broadleaf/703.tif
# dataset/dataset/broadleaf/308.tif
# dataset/dataset/broadleaf/1098.tif
# dataset/dataset/broadleaf/796.tif
# dataset/dataset/broadleaf/546.tif
# dataset/dataset/broadleaf/323.tif
# dataset/dataset/broadleaf/583.tif
# dataset/dataset/broadleaf/1191.tif
# dataset/dataset/broadleaf/318.tif
# dataset/dataset/broadleaf/685.tif
# dataset/dataset/broadleaf/954.tif
# dataset/dataset/broadleaf/380.tif
# dataset/dataset/broadleaf/1097.tif
# dataset/dataset/broadleaf/117.tif
# dataset/dataset/broadleaf/1001.tif
# dataset/dataset/broadleaf/514.tif
# dataset/dataset/broadleaf/731.tif
# dataset/dataset/broadleaf/354.tif
# dataset/dataset/broadleaf/606.tif
# dataset/dataset/broadleaf/520.tif
# dataset/dataset/broadleaf/676.tif
# dataset/dataset/broadleaf/1170.tif
# dataset/dataset/broadleaf/190.tif
# dataset/dataset/broadleaf/1134.tif
# dataset/dataset/broadleaf/896.tif
# dataset/dataset/broadleaf/1040.tif
# dataset/dataset/broadleaf/619.tif
# dataset/dataset/broadleaf/910.tif
# dataset/dataset/broadleaf/388.tif
# dataset/dataset/broadleaf/846.tif
# dataset/dataset/broadleaf/993.tif
# dataset/dataset/broadleaf/172.tif
# dataset/dataset/broadleaf/841.tif
# dataset/dataset/broadleaf/801.tif
# dataset/dataset/broadleaf/1054.tif
# dataset/dataset/broadleaf/636.tif
# dataset/dataset/broadleaf/1079.tif
# dataset/dataset/broadleaf/12.tif
# dataset/dataset/broadleaf/1042.tif
# dataset/dataset/broadleaf/74.tif
# dataset/dataset/broadleaf/497.tif
# dataset/dataset/broadleaf/522.tif
# dataset/dataset/broadleaf/601.tif
# dataset/dataset/broadleaf/902.tif
# dataset/dataset/broadleaf/480.tif
# dataset/dataset/broadleaf/683.tif
# dataset/dataset/broadleaf/515.tif
# dataset/dataset/broadleaf/1075.tif
# dataset/dataset/broadleaf/119.tif
# dataset/dataset/broadleaf/52.tif
# dataset/dataset/broadleaf/1095.tif
# dataset/dataset/broadleaf/625.tif
# dataset/dataset/broadleaf/1076.tif
# dataset/dataset/broadleaf/381.tif
# dataset/dataset/broadleaf/720.tif
# dataset/dataset/broadleaf/878.tif
# dataset/dataset/broadleaf/311.tif
# dataset/dataset/broadleaf/818.tif
# dataset/dataset/broadleaf/876.tif
# dataset/dataset/broadleaf/1162.tif
# dataset/dataset/broadleaf/124.tif
# dataset/dataset/broadleaf/184.tif
# dataset/dataset/broadleaf/825.tif
# dataset/dataset/broadleaf/376.tif
# dataset/dataset/broadleaf/1077.tif
# dataset/dataset/broadleaf/898.tif
# dataset/dataset/broadleaf/603.tif
# dataset/dataset/broadleaf/775.tif
# dataset/dataset/broadleaf/1066.tif
# dataset/dataset/broadleaf/299.tif
# dataset/dataset/broadleaf/713.tif
# dataset/dataset/broadleaf/987.tif
# dataset/dataset/broadleaf/528.tif
# dataset/dataset/broadleaf/250.tif
# dataset/dataset/broadleaf/485.tif
# dataset/dataset/broadleaf/141.tif
# dataset/dataset/broadleaf/511.tif
# dataset/dataset/broadleaf/140.tif
# dataset/dataset/broadleaf/175.tif
# dataset/dataset/broadleaf/132.tif
# dataset/dataset/broadleaf/554.tif
# dataset/dataset/broadleaf/387.tif
# dataset/dataset/broadleaf/967.tif
# dataset/dataset/broadleaf/1056.tif
# dataset/dataset/broadleaf/101.tif
# dataset/dataset/broadleaf/822.tif
# dataset/dataset/broadleaf/687.tif
# dataset/dataset/broadleaf/532.tif
# dataset/dataset/broadleaf/1081.tif
# dataset/dataset/broadleaf/347.tif
# dataset/dataset/broadleaf/533.tif
# dataset/dataset/broadleaf/748.tif
# dataset/dataset/broadleaf/891.tif
# dataset/dataset/broadleaf/600.tif
# dataset/dataset/broadleaf/650.tif
# dataset/dataset/broadleaf/671.tif
# dataset/dataset/broadleaf/839.tif
# dataset/dataset/broadleaf/835.tif
# dataset/dataset/broadleaf/1176.tif
# dataset/dataset/broadleaf/595.tif
# dataset/dataset/broadleaf/81.tif
# dataset/dataset/broadleaf/443.tif
# dataset/dataset/broadleaf/894.tif
# dataset/dataset/broadleaf/847.tif
# dataset/dataset/broadleaf/763.tif
# dataset/dataset/broadleaf/495.tif
# dataset/dataset/broadleaf/391.tif
# dataset/dataset/broadleaf/302.tif
# dataset/dataset/broadleaf/741.tif
# dataset/dataset/broadleaf/858.tif
# dataset/dataset/broadleaf/1045.tif
# dataset/dataset/broadleaf/481.tif
# dataset/dataset/broadleaf/461.tif
# dataset/dataset/broadleaf/883.tif
# dataset/dataset/broadleaf/54.tif
# dataset/dataset/broadleaf/1096.tif
# dataset/dataset/broadleaf/978.tif
# dataset/dataset/broadleaf/789.tif
# dataset/dataset/broadleaf/872.tif
# dataset/dataset/broadleaf/831.tif
# dataset/dataset/broadleaf/402.tif
# dataset/dataset/broadleaf/432.tif
# dataset/dataset/broadleaf/1070.tif
# dataset/dataset/broadleaf/506.tif
# dataset/dataset/broadleaf/1078.tif
# dataset/dataset/broadleaf/55.tif
# dataset/dataset/broadleaf/1060.tif
# dataset/dataset/broadleaf/908.tif
# dataset/dataset/broadleaf/1027.tif
# dataset/dataset/broadleaf/157.tif
# dataset/dataset/broadleaf/161.tif
# dataset/dataset/broadleaf/647.tif
# dataset/dataset/broadleaf/665.tif
# dataset/dataset/broadleaf/655.tif
# dataset/dataset/broadleaf/659.tif
# dataset/dataset/broadleaf/637.tif
# dataset/dataset/broadleaf/1179.tif
# dataset/dataset/broadleaf/428.tif
# dataset/dataset/broadleaf/677.tif
# dataset/dataset/broadleaf/852.tif
# dataset/dataset/broadleaf/620.tif
# dataset/dataset/broadleaf/51.tif
# dataset/dataset/broadleaf/341.tif
# dataset/dataset/broadleaf/1173.tif
# dataset/dataset/broadleaf/1107.tif
# dataset/dataset/broadleaf/616.tif
# dataset/dataset/broadleaf/1087.tif
# dataset/dataset/broadleaf/213.tif
# dataset/dataset/broadleaf/491.tif
# dataset/dataset/broadleaf/661.tif
# dataset/dataset/broadleaf/903.tif
# dataset/dataset/broadleaf/336.tif
# dataset/dataset/broadleaf/466.tif
# dataset/dataset/broadleaf/263.tif
# dataset/dataset/broadleaf/664.tif
# dataset/dataset/broadleaf/544.tif
# dataset/dataset/broadleaf/924.tif
# dataset/dataset/broadleaf/609.tif
# dataset/dataset/broadleaf/424.tif
# dataset/dataset/broadleaf/702.tif
# dataset/dataset/broadleaf/334.tif
# dataset/dataset/broadleaf/91.tif
# dataset/dataset/broadleaf/382.tif
# dataset/dataset/broadleaf/923.tif
# dataset/dataset/broadleaf/521.tif
# dataset/dataset/broadleaf/266.tif
# dataset/dataset/broadleaf/260.tif
# dataset/dataset/broadleaf/960.tif
# dataset/dataset/broadleaf/139.tif
# dataset/dataset/broadleaf/1005.tif
# dataset/dataset/broadleaf/842.tif
# dataset/dataset/broadleaf/1006.tif
# dataset/dataset/broadleaf/1099.tif
# dataset/dataset/broadleaf/122.tif
# dataset/dataset/broadleaf/155.tif
# dataset/dataset/broadleaf/805.tif
# dataset/dataset/broadleaf/441.tif
# dataset/dataset/broadleaf/240.tif
# dataset/dataset/broadleaf/1171.tif
# dataset/dataset/broadleaf/228.tif
# dataset/dataset/broadleaf/496.tif
# dataset/dataset/broadleaf/328.tif
# dataset/dataset/broadleaf/1003.tif
# dataset/dataset/broadleaf/35.tif
# dataset/dataset/broadleaf/913.tif
# dataset/dataset/broadleaf/961.tif
# dataset/dataset/broadleaf/1049.tif
# dataset/dataset/broadleaf/322.tif
# dataset/dataset/broadleaf/69.tif
# dataset/dataset/broadleaf/968.tif
# dataset/dataset/broadleaf/303.tif
# dataset/dataset/broadleaf/1061.tif
# dataset/dataset/broadleaf/711.tif
# dataset/dataset/broadleaf/556.tif
# dataset/dataset/broadleaf/807.tif
# dataset/dataset/broadleaf/281.tif
# dataset/dataset/broadleaf/454.tif
# dataset/dataset/broadleaf/742.tif
# dataset/dataset/broadleaf/1130.tif
# dataset/dataset/broadleaf/1085.tif
# dataset/dataset/broadleaf/922.tif
# dataset/dataset/broadleaf/36.tif
# dataset/dataset/broadleaf/110.tif
# dataset/dataset/broadleaf/436.tif
# dataset/dataset/broadleaf/785.tif
# dataset/dataset/broadleaf/255.tif
# dataset/dataset/broadleaf/949.tif
# dataset/dataset/broadleaf/407.tif
# dataset/dataset/broadleaf/330.tif
# dataset/dataset/broadleaf/594.tif
# dataset/dataset/broadleaf/154.tif
# dataset/dataset/broadleaf/89.tif
# dataset/dataset/broadleaf/693.tif
# dataset/dataset/broadleaf/335.tif
# dataset/dataset/broadleaf/1086.tif
# dataset/dataset/broadleaf/718.tif
# dataset/dataset/broadleaf/1126.tif
# dataset/dataset/broadleaf/153.tif
# dataset/dataset/broadleaf/174.tif
# dataset/dataset/broadleaf/930.tif
# dataset/dataset/broadleaf/513.tif
# dataset/dataset/broadleaf/1104.tif
# dataset/dataset/broadleaf/392.tif
# dataset/dataset/broadleaf/1147.tif
# dataset/dataset/broadleaf/427.tif
# dataset/dataset/broadleaf/750.tif
# dataset/dataset/broadleaf/284.tif
# dataset/dataset/broadleaf/386.tif
# dataset/dataset/broadleaf/187.tif
# dataset/dataset/broadleaf/147.tif
# dataset/dataset/broadleaf/518.tif
# dataset/dataset/broadleaf/1051.tif
# dataset/dataset/broadleaf/840.tif
# dataset/dataset/broadleaf/585.tif
# dataset/dataset/broadleaf/799.tif
# dataset/dataset/broadleaf/1168.tif
# dataset/dataset/broadleaf/933.tif
# dataset/dataset/broadleaf/366.tif
# dataset/dataset/broadleaf/927.tif
# dataset/dataset/broadleaf/979.tif
# dataset/dataset/broadleaf/751.tif
# dataset/dataset/broadleaf/1148.tif
# dataset/dataset/broadleaf/430.tif
# dataset/dataset/broadleaf/568.tif
# dataset/dataset/broadleaf/602.tif
# dataset/dataset/broadleaf/159.tif
# dataset/dataset/broadleaf/1004.tif
# dataset/dataset/broadleaf/462.tif
# dataset/dataset/broadleaf/849.tif
# dataset/dataset/broadleaf/475.tif
# dataset/dataset/broadleaf/280.tif
# dataset/dataset/broadleaf/409.tif
# dataset/dataset/broadleaf/901.tif
# dataset/dataset/broadleaf/403.tif
# dataset/dataset/broadleaf/582.tif
# dataset/dataset/broadleaf/708.tif
# dataset/dataset/broadleaf/875.tif
# dataset/dataset/broadleaf/973.tif
# dataset/dataset/broadleaf/63.tif
# dataset/dataset/broadleaf/346.tif
# dataset/dataset/broadleaf/186.tif
# dataset/dataset/broadleaf/434.tif
# dataset/dataset/broadleaf/971.tif
# dataset/dataset/broadleaf/941.tif
# dataset/dataset/broadleaf/790.tif
# dataset/dataset/broadleaf/762.tif
# dataset/dataset/broadleaf/191.tif
# dataset/dataset/broadleaf/1121.tif
# dataset/dataset/broadleaf/1146.tif
# dataset/dataset/broadleaf/1091.tif
# dataset/dataset/broadleaf/684.tif
# dataset/dataset/broadleaf/77.tif
# dataset/dataset/broadleaf/418.tif
# dataset/dataset/broadleaf/1009.tif
# dataset/dataset/broadleaf/1135.tif
# dataset/dataset/broadleaf/121.tif
# dataset/dataset/broadleaf/709.tif
# dataset/dataset/broadleaf/422.tif
# dataset/dataset/broadleaf/173.tif
# dataset/dataset/broadleaf/25.tif
# dataset/dataset/broadleaf/643.tif
# dataset/dataset/broadleaf/1069.tif
# dataset/dataset/broadleaf/34.tif
# dataset/dataset/broadleaf/1063.tif
# dataset/dataset/broadleaf/75.tif
# dataset/dataset/broadleaf/244.tif
# dataset/dataset/broadleaf/997.tif
# dataset/dataset/broadleaf/632.tif
# dataset/dataset/broadleaf/1028.tif
# dataset/dataset/broadleaf/305.tif
# dataset/dataset/broadleaf/164.tif
# dataset/dataset/broadleaf/32.tif
# dataset/dataset/broadleaf/1103.tif
# dataset/dataset/broadleaf/166.tif
# dataset/dataset/broadleaf/948.tif
# dataset/dataset/broadleaf/580.tif
# dataset/dataset/broadleaf/1175.tif
# dataset/dataset/broadleaf/699.tif
# dataset/dataset/broadleaf/149.tif
# dataset/dataset/broadleaf/629.tif
# dataset/dataset/broadleaf/778.tif
# dataset/dataset/broadleaf/125.tif
# dataset/dataset/broadleaf/46.tif
# dataset/dataset/broadleaf/597.tif
# dataset/dataset/broadleaf/162.tif
# dataset/dataset/broadleaf/401.tif
# dataset/dataset/broadleaf/740.tif
# dataset/dataset/broadleaf/590.tif
# dataset/dataset/broadleaf/275.tif
# dataset/dataset/broadleaf/704.tif
# dataset/dataset/broadleaf/592.tif
# dataset/dataset/broadleaf/576.tif
# dataset/dataset/broadleaf/797.tif
# dataset/dataset/broadleaf/360.tif
# dataset/dataset/broadleaf/1127.tif
# dataset/dataset/broadleaf/324.tif
# dataset/dataset/broadleaf/211.tif
# dataset/dataset/broadleaf/369.tif
# dataset/dataset/broadleaf/769.tif
# dataset/dataset/broadleaf/1021.tif
# dataset/dataset/broadleaf/649.tif
# dataset/dataset/broadleaf/551.tif
# dataset/dataset/broadleaf/886.tif
# dataset/dataset/broadleaf/666.tif
# dataset/dataset/broadleaf/371.tif
# dataset/dataset/broadleaf/1124.tif
# dataset/dataset/broadleaf/64.tif
# dataset/dataset/broadleaf/130.tif
# dataset/dataset/broadleaf/501.tif
# dataset/dataset/broadleaf/1037.tif
# dataset/dataset/broadleaf/753.tif
# dataset/dataset/broadleaf/199.tif
# dataset/dataset/broadleaf/950.tif
# dataset/dataset/broadleaf/313.tif
# dataset/dataset/broadleaf/112.tif
# dataset/dataset/broadleaf/59.tif
# dataset/dataset/broadleaf/234.tif
# dataset/dataset/broadleaf/1017.tif
# dataset/dataset/broadleaf/43.tif
# dataset/dataset/broadleaf/200.tif
# dataset/dataset/broadleaf/1174.tif
# dataset/dataset/broadleaf/765.tif
# dataset/dataset/broadleaf/999.tif
# dataset/dataset/broadleaf/232.tif
# dataset/dataset/broadleaf/1080.tif
# dataset/dataset/broadleaf/1133.tif
# dataset/dataset/broadleaf/1122.tif
# dataset/dataset/broadleaf/1125.tif
# dataset/dataset/broadleaf/767.tif
# dataset/dataset/broadleaf/621.tif
# dataset/dataset/broadleaf/107.tif
# dataset/dataset/broadleaf/995.tif
# dataset/dataset/broadleaf/921.tif
# dataset/dataset/broadleaf/730.tif
# dataset/dataset/broadleaf/379.tif
# dataset/dataset/broadleaf/1068.tif
# dataset/dataset/broadleaf/247.tif
# dataset/dataset/broadleaf/176.tif
# dataset/dataset/broadleaf/358.tif
# dataset/dataset/broadleaf/681.tif
# dataset/dataset/broadleaf/697.tif
# dataset/dataset/broadleaf/363.tif
# dataset/dataset/broadleaf/1100.tif
# dataset/dataset/broadleaf/755.tif
# dataset/dataset/broadleaf/177.tif
# dataset/dataset/broadleaf/674.tif
# dataset/dataset/broadleaf/726.tif
# dataset/dataset/broadleaf/510.tif
# dataset/dataset/broadleaf/652.tif
# dataset/dataset/broadleaf/373.tif
# dataset/dataset/broadleaf/615.tif
# dataset/dataset/broadleaf/1185.tif
# dataset/dataset/broadleaf/716.tif
# dataset/dataset/broadleaf/810.tif
# dataset/dataset/broadleaf/555.tif
# dataset/dataset/broadleaf/227.tif
# dataset/dataset/broadleaf/426.tif
# dataset/dataset/broadleaf/417.tif
# dataset/dataset/broadleaf/734.tif
# dataset/dataset/broadleaf/212.tif
# dataset/dataset/broadleaf/892.tif
# dataset/dataset/broadleaf/165.tif
# dataset/dataset/broadleaf/529.tif
# dataset/dataset/broadleaf/856.tif
# dataset/dataset/broadleaf/857.tif
# dataset/dataset/broadleaf/845.tif
# dataset/dataset/broadleaf/23.tif
# dataset/dataset/broadleaf/812.tif
# dataset/dataset/broadleaf/456.tif
# dataset/dataset/broadleaf/416.tif
# dataset/dataset/broadleaf/830.tif
# dataset/dataset/broadleaf/189.tif
# dataset/dataset/broadleaf/96.tif
# dataset/dataset/broadleaf/1093.tif
# dataset/dataset/broadleaf/1114.tif
# dataset/dataset/broadleaf/786.tif
# dataset/dataset/broadleaf/690.tif
# dataset/dataset/broadleaf/977.tif
# dataset/dataset/broadleaf/171.tif
# dataset/dataset/broadleaf/1119.tif
# dataset/dataset/broadleaf/133.tif
# dataset/dataset/broadleaf/233.tif
# dataset/dataset/broadleaf/1035.tif
# dataset/dataset/broadleaf/816.tif
# dataset/dataset/broadleaf/1144.tif
# dataset/dataset/broadleaf/516.tif
# dataset/dataset/broadleaf/291.tif
# dataset/dataset/broadleaf/946.tif
# dataset/dataset/broadleaf/552.tif
# dataset/dataset/broadleaf/648.tif
# dataset/dataset/broadleaf/834.tif
# dataset/dataset/broadleaf/53.tif
# dataset/dataset/broadleaf/40.tif
# dataset/dataset/broadleaf/1.tif
# dataset/dataset/broadleaf/918.tif
# dataset/dataset/broadleaf/87.tif
# dataset/dataset/broadleaf/1071.tif
# dataset/dataset/broadleaf/398.tif
# dataset/dataset/broadleaf/855.tif
# dataset/dataset/broadleaf/779.tif
# dataset/dataset/broadleaf/477.tif
# dataset/dataset/broadleaf/1000.tif
# dataset/dataset/broadleaf/18.tif
# dataset/dataset/broadleaf/246.tif
# dataset/dataset/broadleaf/128.tif
# dataset/dataset/broadleaf/809.tif
# dataset/dataset/broadleaf/721.tif
# dataset/dataset/broadleaf/1067.tif
# dataset/dataset/broadleaf/209.tif
# dataset/dataset/broadleaf/1053.tif
# dataset/dataset/broadleaf/394.tif
# dataset/dataset/broadleaf/1020.tif
# dataset/dataset/broadleaf/1048.tif
# dataset/dataset/broadleaf/672.tif
# dataset/dataset/broadleaf/727.tif
# dataset/dataset/broadleaf/326.tif
# dataset/dataset/broadleaf/963.tif
# dataset/dataset/broadleaf/473.tif
# dataset/dataset/broadleaf/49.tif
# dataset/dataset/broadleaf/294.tif
# dataset/dataset/broadleaf/746.tif
# dataset/dataset/broadleaf/670.tif
# dataset/dataset/broadleaf/565.tif
# dataset/dataset/broadleaf/29.tif
# dataset/dataset/broadleaf/688.tif
# dataset/dataset/broadleaf/288.tif
# dataset/dataset/broadleaf/238.tif
# dataset/dataset/broadleaf/264.tif
# dataset/dataset/broadleaf/269.tif
# dataset/dataset/broadleaf/420.tif
# dataset/dataset/broadleaf/1059.tif
# dataset/dataset/broadleaf/1024.tif
# dataset/dataset/broadleaf/906.tif
# dataset/dataset/broadleaf/15.tif
# dataset/dataset/broadleaf/1129.tif
# dataset/dataset/broadleaf/558.tif
# dataset/dataset/broadleaf/183.tif
# dataset/dataset/broadleaf/955.tif
# dataset/dataset/broadleaf/102.tif
# dataset/dataset/broadleaf/106.tif
# dataset/dataset/broadleaf/469.tif
# dataset/dataset/broadleaf/774.tif
# dataset/dataset/broadleaf/651.tif
# dataset/dataset/broadleaf/985.tif
# dataset/dataset/broadleaf/1089.tif
# dataset/dataset/broadleaf/395.tif
# dataset/dataset/broadleaf/811.tif
# dataset/dataset/broadleaf/706.tif
# dataset/dataset/broadleaf/605.tif
# dataset/dataset/broadleaf/1118.tif
# dataset/dataset/broadleaf/530.tif
# dataset/dataset/broadleaf/242.tif
# dataset/dataset/broadleaf/412.tif
# dataset/dataset/broadleaf/80.tif
# dataset/dataset/broadleaf/550.tif
# dataset/dataset/broadleaf/743.tif
# dataset/dataset/broadleaf/1166.tif
# dataset/dataset/broadleaf/405.tif
# dataset/dataset/broadleaf/1181.tif
# dataset/dataset/broadleaf/826.tif
# dataset/dataset/broadleaf/68.tif
# dataset/dataset/broadleaf/136.tif
# dataset/dataset/broadleaf/682.tif
# dataset/dataset/broadleaf/729.tif
# dataset/dataset/broadleaf/745.tif
# dataset/dataset/broadleaf/547.tif
# dataset/dataset/broadleaf/526.tif
# dataset/dataset/broadleaf/167.tif
# dataset/dataset/broadleaf/656.tif
# dataset/dataset/broadleaf/1138.tif
# dataset/dataset/broadleaf/617.tif
# dataset/dataset/broadleaf/1108.tif
# dataset/dataset/broadleaf/254.tif
# dataset/dataset/broadleaf/463.tif
# dataset/dataset/broadleaf/488.tif
# dataset/dataset/broadleaf/285.tif
# dataset/dataset/broadleaf/490.tif
# dataset/dataset/broadleaf/678.tif
# dataset/dataset/broadleaf/1084.tif
# dataset/dataset/broadleaf/361.tif
# dataset/dataset/broadleaf/223.tif
# dataset/dataset/broadleaf/338.tif
# dataset/dataset/broadleaf/1143.tif
# dataset/dataset/broadleaf/994.tif
# dataset/dataset/broadleaf/566.tif
# dataset/dataset/broadleaf/248.tif
# dataset/dataset/broadleaf/203.tif
# dataset/dataset/broadleaf/290.tif
# dataset/dataset/broadleaf/795.tif
# dataset/dataset/broadleaf/887.tif
# dataset/dataset/broadleaf/766.tif
# dataset/dataset/broadleaf/85.tif
# dataset/dataset/broadleaf/717.tif
# dataset/dataset/broadleaf/44.tif
# dataset/dataset/broadleaf/21.tif
# dataset/dataset/broadleaf/1156.tif
# dataset/dataset/broadleaf/37.tif
# dataset/dataset/broadleaf/578.tif
# dataset/dataset/broadleaf/912.tif
# dataset/dataset/broadleaf/628.tif
# dataset/dataset/broadleaf/241.tif
# dataset/dataset/broadleaf/30.tif
# dataset/dataset/broadleaf/339.tif
# dataset/dataset/broadleaf/579.tif
# dataset/dataset/broadleaf/206.tif
# dataset/dataset/broadleaf/273.tif
# dataset/dataset/broadleaf/7.tif
# dataset/dataset/broadleaf/928.tif
# dataset/dataset/broadleaf/389.tif
# dataset/dataset/broadleaf/362.tif
# dataset/dataset/broadleaf/4.tif
# dataset/dataset/broadleaf/286.tif
# dataset/dataset/broadleaf/938.tif
# dataset/dataset/broadleaf/640.tif
# dataset/dataset/broadleaf/873.tif
# dataset/dataset/broadleaf/862.tif
# dataset/dataset/broadleaf/1112.tif
# dataset/dataset/broadleaf/882.tif
# dataset/dataset/broadleaf/1145.tif
# dataset/dataset/broadleaf/549.tif
# dataset/dataset/broadleaf/888.tif
# dataset/dataset/broadleaf/991.tif
# dataset/dataset/broadleaf/754.tif
# dataset/dataset/broadleaf/507.tif
# dataset/dataset/broadleaf/178.tif
# dataset/dataset/broadleaf/267.tif
# dataset/dataset/broadleaf/1113.tif
# dataset/dataset/broadleaf/926.tif
# dataset/dataset/broadleaf/114.tif
# dataset/dataset/broadleaf/143.tif
# dataset/dataset/broadleaf/1110.tif
# dataset/dataset/broadleaf/1149.tif
# dataset/dataset/broadleaf/179.tif
# dataset/dataset/broadleaf/56.tif
# dataset/dataset/broadleaf/851.tif
# dataset/dataset/broadleaf/679.tif
# dataset/dataset/broadleaf/120.tif
# dataset/dataset/broadleaf/970.tif
# dataset/dataset/broadleaf/548.tif
# dataset/dataset/broadleaf/471.tif
# dataset/dataset/broadleaf/127.tif
# dataset/dataset/broadleaf/468.tif
# dataset/dataset/broadleaf/1102.tif
# dataset/dataset/broadleaf/723.tif
# dataset/dataset/broadleaf/645.tif
# dataset/dataset/broadleaf/976.tif
# dataset/dataset/broadleaf/893.tif
# dataset/dataset/broadleaf/701.tif
# dataset/dataset/broadleaf/828.tif
# dataset/dataset/broadleaf/800.tif
# dataset/dataset/broadleaf/844.tif
# dataset/dataset/broadleaf/736.tif
# dataset/dataset/broadleaf/932.tif
# dataset/dataset/broadleaf/38.tif
# dataset/dataset/broadleaf/383.tif
# dataset/dataset/broadleaf/827.tif
# dataset/dataset/broadleaf/1014.tif
# dataset/dataset/broadleaf/667.tif
# dataset/dataset/broadleaf/897.tif
# dataset/dataset/broadleaf/493.tif
# dataset/dataset/broadleaf/838.tif
# dataset/dataset/broadleaf/832.tif
# dataset/dataset/broadleaf/877.tif
# dataset/dataset/broadleaf/349.tif
# dataset/dataset/broadleaf/6.tif
# dataset/dataset/broadleaf/415.tif
# dataset/dataset/broadleaf/126.tif
# dataset/dataset/broadleaf/1013.tif
# dataset/dataset/broadleaf/459.tif
# dataset/dataset/broadleaf/160.tif
# dataset/dataset/broadleaf/781.tif
# dataset/dataset/broadleaf/262.tif
# dataset/dataset/broadleaf/696.tif
# dataset/dataset/broadleaf/185.tif
# dataset/dataset/broadleaf/217.tif
# dataset/dataset/broadleaf/772.tif
# dataset/dataset/broadleaf/668.tif
# dataset/dataset/broadleaf/559.tif
# dataset/dataset/broadleaf/225.tif
# dataset/dataset/broadleaf/455.tif
# dataset/dataset/broadleaf/749.tif
# dataset/dataset/broadleaf/458.tif
# dataset/dataset/broadleaf/98.tif
# dataset/dataset/broadleaf/653.tif
# dataset/dataset/broadleaf/866.tif
# dataset/dataset/broadleaf/791.tif
# dataset/dataset/broadleaf/859.tif
# dataset/dataset/broadleaf/1187.tif
# dataset/dataset/broadleaf/27.tif
# dataset/dataset/broadleaf/1038.tif
# dataset/dataset/broadleaf/33.tif
# dataset/dataset/broadleaf/1055.tif
# dataset/dataset/broadleaf/635.tif
# dataset/dataset/broadleaf/561.tif
# dataset/dataset/broadleaf/108.tif
# dataset/dataset/broadleaf/919.tif
# dataset/dataset/broadleaf/586.tif
# dataset/dataset/broadleaf/879.tif
# dataset/dataset/broadleaf/1123.tif
# dataset/dataset/broadleaf/783.tif
# dataset/dataset/grass/
# dataset/dataset/grass/660.tif
# dataset/dataset/grass/3287.tif
# dataset/dataset/grass/613.tif
# dataset/dataset/grass/1589.tif
# dataset/dataset/grass/540.tif
# dataset/dataset/grass/83.tif
# dataset/dataset/grass/587.tif
# dataset/dataset/grass/1492.tif
# dataset/dataset/grass/2881.tif
# dataset/dataset/grass/2092.tif
# dataset/dataset/grass/733.tif
# dataset/dataset/grass/123.tif
# dataset/dataset/grass/2252.tif
# dataset/dataset/grass/2926.tif
# dataset/dataset/grass/2935.tif
# dataset/dataset/grass/817.tif
# dataset/dataset/grass/169.tif
# dataset/dataset/grass/287.tif
# dataset/dataset/grass/2742.tif
# dataset/dataset/grass/142.tif
# dataset/dataset/grass/452.tif
# dataset/dataset/grass/1141.tif
# dataset/dataset/grass/1284.tif
# dataset/dataset/grass/2105.tif
# dataset/dataset/grass/1516.tif
# dataset/dataset/grass/236.tif
# dataset/dataset/grass/571.tif
# dataset/dataset/grass/2179.tif
# dataset/dataset/grass/756.tif
# dataset/dataset/grass/1008.tif
# dataset/dataset/grass/1043.tif
# dataset/dataset/grass/3382.tif
# dataset/dataset/grass/3252.tif
# dataset/dataset/grass/3520.tif
# dataset/dataset/grass/2780.tif
# dataset/dataset/grass/3303.tif
# dataset/dataset/grass/1981.tif
# dataset/dataset/grass/1548.tif
# dataset/dataset/grass/1406.tif
# dataset/dataset/grass/531.tif
# dataset/dataset/grass/1413.tif
# dataset/dataset/grass/2535.tif
# dataset/dataset/grass/1354.tif
# dataset/dataset/grass/2975.tif
# dataset/dataset/grass/3449.tif
# dataset/dataset/grass/2447.tif
# dataset/dataset/grass/3411.tif
# dataset/dataset/grass/314.tif
# dataset/dataset/grass/1159.tif
# dataset/dataset/grass/1231.tif
# dataset/dataset/grass/2182.tif
# dataset/dataset/grass/1165.tif
# dataset/dataset/grass/1111.tif
# dataset/dataset/grass/137.tif
# dataset/dataset/grass/2812.tif
# dataset/dataset/grass/3472.tif
# dataset/dataset/grass/622.tif
# dataset/dataset/grass/2128.tif
# dataset/dataset/grass/192.tif
# dataset/dataset/grass/3260.tif
# dataset/dataset/grass/641.tif
# dataset/dataset/grass/2244.tif
# dataset/dataset/grass/1074.tif
# dataset/dataset/grass/2263.tif
# dataset/dataset/grass/1999.tif
# dataset/dataset/grass/368.tif
# dataset/dataset/grass/700.tif
# dataset/dataset/grass/1695.tif
# dataset/dataset/grass/2048.tif
# dataset/dataset/grass/884.tif
# dataset/dataset/grass/2175.tif
# dataset/dataset/grass/3314.tif
# dataset/dataset/grass/1783.tif
# dataset/dataset/grass/870.tif
# dataset/dataset/grass/390.tif
# dataset/dataset/grass/1829.tif
# dataset/dataset/grass/2554.tif
# dataset/dataset/grass/1831.tif
# dataset/dataset/grass/482.tif
# dataset/dataset/grass/624.tif
# dataset/dataset/grass/2824.tif
# dataset/dataset/grass/1161.tif
# dataset/dataset/grass/2640.tif
# dataset/dataset/grass/596.tif
# dataset/dataset/grass/1598.tif
# dataset/dataset/grass/1316.tif
# dataset/dataset/grass/2246.tif
# dataset/dataset/grass/1900.tif
# dataset/dataset/grass/2658.tif
# dataset/dataset/grass/115.tif
# dataset/dataset/grass/3416.tif
# dataset/dataset/grass/440.tif
# dataset/dataset/grass/2766.tif
# dataset/dataset/grass/419.tif
# dataset/dataset/grass/909.tif
# dataset/dataset/grass/2473.tif
# dataset/dataset/grass/957.tif
# dataset/dataset/grass/144.tif
# dataset/dataset/grass/3194.tif
# dataset/dataset/grass/777.tif
# dataset/dataset/grass/446.tif
# dataset/dataset/grass/152.tif
# dataset/dataset/grass/695.tif
# dataset/dataset/grass/2981.tif
# dataset/dataset/grass/2702.tif
# dataset/dataset/grass/557.tif
# dataset/dataset/grass/1065.tif
# dataset/dataset/grass/989.tif
# dataset/dataset/grass/1556.tif
# dataset/dataset/grass/1555.tif
# dataset/dataset/grass/1278.tif
# dataset/dataset/grass/1919.tif
# dataset/dataset/grass/2412.tif
# dataset/dataset/grass/3502.tif
# dataset/dataset/grass/1456.tif
# dataset/dataset/grass/2832.tif
# dataset/dataset/grass/343.tif
# dataset/dataset/grass/1865.tif
# dataset/dataset/grass/498.tif
# dataset/dataset/grass/2170.tif
# dataset/dataset/grass/943.tif
# dataset/dataset/grass/2526.tif
# dataset/dataset/grass/3207.tif
# dataset/dataset/grass/484.tif
# dataset/dataset/grass/2837.tif
# dataset/dataset/grass/296.tif
# dataset/dataset/grass/732.tif
# dataset/dataset/grass/2983.tif
# dataset/dataset/grass/2879.tif
# dataset/dataset/grass/2234.tif
# dataset/dataset/grass/39.tif
# dataset/dataset/grass/2136.tif
# dataset/dataset/grass/2453.tif
# dataset/dataset/grass/1730.tif
# dataset/dataset/grass/2307.tif
# dataset/dataset/grass/3359.tif
# dataset/dataset/grass/2789.tif
# dataset/dataset/grass/3352.tif
# dataset/dataset/grass/573.tif
# dataset/dataset/grass/3458.tif
# dataset/dataset/grass/2354.tif
# dataset/dataset/grass/3300.tif
# dataset/dataset/grass/815.tif
# dataset/dataset/grass/1934.tif
# dataset/dataset/grass/3518.tif
# dataset/dataset/grass/2984.tif
# dataset/dataset/grass/1379.tif
# dataset/dataset/grass/3033.tif
# dataset/dataset/grass/1446.tif
# dataset/dataset/grass/1994.tif
# dataset/dataset/grass/680.tif
# dataset/dataset/grass/3261.tif
# dataset/dataset/grass/1939.tif
# dataset/dataset/grass/577.tif
# dataset/dataset/grass/198.tif
# dataset/dataset/grass/2595.tif
# dataset/dataset/grass/1820.tif
# dataset/dataset/grass/952.tif
# dataset/dataset/grass/768.tif
# dataset/dataset/grass/2855.tif
# dataset/dataset/grass/76.tif
# dataset/dataset/grass/2243.tif
# dataset/dataset/grass/2371.tif
# dataset/dataset/grass/1169.tif
# dataset/dataset/grass/414.tif
# dataset/dataset/grass/1639.tif
# dataset/dataset/grass/253.tif
# dataset/dataset/grass/3445.tif
# dataset/dataset/grass/2565.tif
# dataset/dataset/grass/453.tif
# dataset/dataset/grass/2787.tif
# dataset/dataset/grass/478.tif
# dataset/dataset/grass/1871.tif
# dataset/dataset/grass/1044.tif
# dataset/dataset/grass/2784.tif
# dataset/dataset/grass/342.tif
# dataset/dataset/grass/1287.tif
# dataset/dataset/grass/770.tif
# dataset/dataset/grass/1360.tif
# dataset/dataset/grass/1809.tif
# dataset/dataset/grass/1504.tif
# dataset/dataset/grass/2957.tif
# dataset/dataset/grass/3269.tif
# dataset/dataset/grass/292.tif
# dataset/dataset/grass/2440.tif
# dataset/dataset/grass/492.tif
# dataset/dataset/grass/483.tif
# dataset/dataset/grass/2976.tif
# dataset/dataset/grass/1408.tif
# dataset/dataset/grass/1789.tif
# dataset/dataset/grass/2204.tif
# dataset/dataset/grass/1374.tif
# dataset/dataset/grass/3177.tif
# dataset/dataset/grass/1708.tif
# dataset/dataset/grass/5.tif
# dataset/dataset/grass/348.tif
# dataset/dataset/grass/669.tif
# dataset/dataset/grass/3372.tif
# dataset/dataset/grass/2411.tif
# dataset/dataset/grass/523.tif
# dataset/dataset/grass/2736.tif
# dataset/dataset/grass/451.tif
# dataset/dataset/grass/1792.tif
# dataset/dataset/grass/1767.tif
# dataset/dataset/grass/378.tif
# dataset/dataset/grass/2885.tif
# dataset/dataset/grass/1655.tif
# dataset/dataset/grass/1012.tif
# dataset/dataset/grass/1811.tif
# dataset/dataset/grass/2902.tif
# dataset/dataset/grass/998.tif
# dataset/dataset/grass/2951.tif
# dataset/dataset/grass/2025.tif
# dataset/dataset/grass/2346.tif
# dataset/dataset/grass/3473.tif
# dataset/dataset/grass/3056.tif
# dataset/dataset/grass/752.tif
# dataset/dataset/grass/1911.tif
# dataset/dataset/grass/1363.tif
# dataset/dataset/grass/1326.tif
# dataset/dataset/grass/1928.tif
# dataset/dataset/grass/942.tif
# dataset/dataset/grass/3044.tif
# dataset/dataset/grass/1642.tif
# dataset/dataset/grass/534.tif
# dataset/dataset/grass/2999.tif
# dataset/dataset/grass/1481.tif
# dataset/dataset/grass/2217.tif
# dataset/dataset/grass/439.tif
# dataset/dataset/grass/2378.tif
# dataset/dataset/grass/771.tif
# dataset/dataset/grass/3002.tif
# dataset/dataset/grass/3295.tif
# dataset/dataset/grass/2873.tif
# dataset/dataset/grass/1088.tif
# dataset/dataset/grass/758.tif
# dataset/dataset/grass/1678.tif
# dataset/dataset/grass/2763.tif
# dataset/dataset/grass/2725.tif
# dataset/dataset/grass/591.tif
# ...
# dataset/dataset/soybean/2375.tif
# dataset/dataset/soybean/2616.tif
# dataset/dataset/soybean/1113.tif
# dataset/dataset/soybean/3004.tif
# dataset/dataset/soybean/6117.tif
# dataset/dataset/soybean/2891.tif
# dataset/dataset/soybean/2707.tif
# dataset/dataset/soybean/5682.tif
# dataset/dataset/soybean/4843.tif
# dataset/dataset/soybean/4939.tif
# dataset/dataset/soybean/926.tif
# dataset/dataset/soybean/3424.tif
# dataset/dataset/soybean/7010.tif
# dataset/dataset/soybean/6777.tif
# dataset/dataset/soybean/2423.tif
# dataset/dataset/soybean/1652.tif
# dataset/dataset/soybean/1355.tif
# dataset/dataset/soybean/1465.tif
# dataset/dataset/soybean/4698.tif
# dataset/dataset/soybean/3804.tif
# dataset/dataset/soybean/5108.tif
# dataset/dataset/soybean/2838.tif
# dataset/dataset/soybean/3351.tif
# dataset/dataset/soybean/6631.tif
# dataset/dataset/soybean/114.tif
# dataset/dataset/soybean/5207.tif
# dataset/dataset/soybean/3305.tif
# dataset/dataset/soybean/5440.tif
# dataset/dataset/soybean/143.tif
# dataset/dataset/soybean/1110.tif
# dataset/dataset/soybean/3126.tif
# dataset/dataset/soybean/3563.tif
# dataset/dataset/soybean/6882.tif
# dataset/dataset/soybean/2339.tif
# dataset/dataset/soybean/1149.tif
# dataset/dataset/soybean/4065.tif
# dataset/dataset/soybean/4069.tif
# dataset/dataset/soybean/2528.tif
# dataset/dataset/soybean/7325.tif
# dataset/dataset/soybean/5566.tif
# dataset/dataset/soybean/6486.tif
# dataset/dataset/soybean/179.tif
# dataset/dataset/soybean/6732.tif
# dataset/dataset/soybean/5499.tif
# dataset/dataset/soybean/6896.tif
# dataset/dataset/soybean/3274.tif
# dataset/dataset/soybean/2300.tif
# dataset/dataset/soybean/7267.tif
# dataset/dataset/soybean/6187.tif
# dataset/dataset/soybean/56.tif
# dataset/dataset/soybean/5300.tif
# dataset/dataset/soybean/4300.tif
# dataset/dataset/soybean/6476.tif
# dataset/dataset/soybean/851.tif
# dataset/dataset/soybean/4265.tif
# dataset/dataset/soybean/5126.tif
# dataset/dataset/soybean/5605.tif
# dataset/dataset/soybean/3384.tif
# dataset/dataset/soybean/5561.tif
# dataset/dataset/soybean/2913.tif
# dataset/dataset/soybean/679.tif
# dataset/dataset/soybean/2582.tif
# dataset/dataset/soybean/5187.tif
# dataset/dataset/soybean/3914.tif
# dataset/dataset/soybean/7274.tif
# dataset/dataset/soybean/5809.tif
# dataset/dataset/soybean/1751.tif
# dataset/dataset/soybean/2750.tif
# dataset/dataset/soybean/3523.tif
# dataset/dataset/soybean/2738.tif
# dataset/dataset/soybean/4350.tif
# dataset/dataset/soybean/4574.tif
# dataset/dataset/soybean/120.tif
# dataset/dataset/soybean/6607.tif
# dataset/dataset/soybean/1473.tif
# dataset/dataset/soybean/5963.tif
# dataset/dataset/soybean/7317.tif
# dataset/dataset/soybean/2912.tif
# dataset/dataset/soybean/6600.tif
# dataset/dataset/soybean/3519.tif
# dataset/dataset/soybean/3708.tif
# dataset/dataset/soybean/4124.tif
# dataset/dataset/soybean/1720.tif
# dataset/dataset/soybean/4723.tif
# dataset/dataset/soybean/970.tif
# dataset/dataset/soybean/4520.tif
# dataset/dataset/soybean/6159.tif
# dataset/dataset/soybean/3540.tif
# dataset/dataset/soybean/3145.tif
# dataset/dataset/soybean/2914.tif
# dataset/dataset/soybean/3395.tif
# dataset/dataset/soybean/5331.tif
# dataset/dataset/soybean/1553.tif
# dataset/dataset/soybean/4410.tif
# dataset/dataset/soybean/3864.tif
# dataset/dataset/soybean/548.tif
# dataset/dataset/soybean/1596.tif
# dataset/dataset/soybean/6186.tif
# dataset/dataset/soybean/2069.tif
# dataset/dataset/soybean/4003.tif
# dataset/dataset/soybean/471.tif
# dataset/dataset/soybean/127.tif
# dataset/dataset/soybean/1908.tif
# dataset/dataset/soybean/3318.tif
# dataset/dataset/soybean/6583.tif
# dataset/dataset/soybean/2131.tif
# dataset/dataset/soybean/4541.tif
# dataset/dataset/soybean/4127.tif
# dataset/dataset/soybean/468.tif
# dataset/dataset/soybean/1877.tif
# dataset/dataset/soybean/5969.tif
# dataset/dataset/soybean/5088.tif
# dataset/dataset/soybean/3404.tif
# dataset/dataset/soybean/3432.tif
# dataset/dataset/soybean/7329.tif
# dataset/dataset/soybean/1421.tif
# dataset/dataset/soybean/1102.tif
# dataset/dataset/soybean/4032.tif
# dataset/dataset/soybean/3912.tif
# dataset/dataset/soybean/2026.tif
# dataset/dataset/soybean/4282.tif
# dataset/dataset/soybean/723.tif
# dataset/dataset/soybean/3155.tif
# dataset/dataset/soybean/5527.tif
# dataset/dataset/soybean/4644.tif
# dataset/dataset/soybean/3045.tif
# dataset/dataset/soybean/4865.tif
# dataset/dataset/soybean/645.tif
# dataset/dataset/soybean/2490.tif
# dataset/dataset/soybean/5716.tif
# dataset/dataset/soybean/6391.tif
# dataset/dataset/soybean/976.tif
# dataset/dataset/soybean/2550.tif
# dataset/dataset/soybean/4599.tif
# dataset/dataset/soybean/2724.tif
# dataset/dataset/soybean/3830.tif
# dataset/dataset/soybean/893.tif
# dataset/dataset/soybean/3850.tif
# dataset/dataset/soybean/5416.tif
# dataset/dataset/soybean/6174.tif
# dataset/dataset/soybean/6459.tif
# dataset/dataset/soybean/5396.tif
# dataset/dataset/soybean/701.tif
# dataset/dataset/soybean/5136.tif
# dataset/dataset/soybean/828.tif
# dataset/dataset/soybean/6053.tif
# dataset/dataset/soybean/5195.tif
# dataset/dataset/soybean/3659.tif
# dataset/dataset/soybean/3288.tif
# dataset/dataset/soybean/5633.tif
# dataset/dataset/soybean/7128.tif
# dataset/dataset/soybean/1387.tif
# dataset/dataset/soybean/1195.tif
# dataset/dataset/soybean/800.tif
# dataset/dataset/soybean/4551.tif
# dataset/dataset/soybean/1455.tif
# dataset/dataset/soybean/5481.tif
# dataset/dataset/soybean/5510.tif
# dataset/dataset/soybean/5337.tif
# dataset/dataset/soybean/6929.tif
# dataset/dataset/soybean/1270.tif
# dataset/dataset/soybean/3544.tif
# dataset/dataset/soybean/1970.tif
# dataset/dataset/soybean/1945.tif
# dataset/dataset/soybean/6505.tif
# dataset/dataset/soybean/3790.tif
# dataset/dataset/soybean/3536.tif
# dataset/dataset/soybean/844.tif
# dataset/dataset/soybean/4614.tif
# dataset/dataset/soybean/5504.tif
# dataset/dataset/soybean/3410.tif
# dataset/dataset/soybean/4075.tif
# dataset/dataset/soybean/736.tif
# dataset/dataset/soybean/5795.tif
# dataset/dataset/soybean/3317.tif
# dataset/dataset/soybean/4657.tif
# dataset/dataset/soybean/5239.tif
# dataset/dataset/soybean/3861.tif
# dataset/dataset/soybean/932.tif
# dataset/dataset/soybean/2921.tif
# dataset/dataset/soybean/6971.tif
# dataset/dataset/soybean/3060.tif
# dataset/dataset/soybean/2358.tif
# dataset/dataset/soybean/6400.tif
# dataset/dataset/soybean/7067.tif
# dataset/dataset/soybean/3673.tif
# dataset/dataset/soybean/1272.tif
# dataset/dataset/soybean/38.tif
# dataset/dataset/soybean/383.tif
# dataset/dataset/soybean/5127.tif
# dataset/dataset/soybean/6215.tif
# dataset/dataset/soybean/6071.tif
# dataset/dataset/soybean/3190.tif
# dataset/dataset/soybean/3564.tif
# dataset/dataset/soybean/1977.tif
# dataset/dataset/soybean/3884.tif
# dataset/dataset/soybean/6549.tif
# dataset/dataset/soybean/4434.tif
# dataset/dataset/soybean/4376.tif
# dataset/dataset/soybean/2083.tif
# dataset/dataset/soybean/5035.tif
# dataset/dataset/soybean/5180.tif
# dataset/dataset/soybean/4857.tif
# dataset/dataset/soybean/2340.tif
# dataset/dataset/soybean/1319.tif
# dataset/dataset/soybean/3263.tif
# dataset/dataset/soybean/6919.tif
# dataset/dataset/soybean/827.tif
# dataset/dataset/soybean/2796.tif
# dataset/dataset/soybean/1501.tif
# dataset/dataset/soybean/1560.tif
# dataset/dataset/soybean/1014.tif
# dataset/dataset/soybean/5328.tif
# dataset/dataset/soybean/6506.tif
# dataset/dataset/soybean/667.tif
# dataset/dataset/soybean/7375.tif
# dataset/dataset/soybean/897.tif
# dataset/dataset/soybean/1682.tif
# dataset/dataset/soybean/6036.tif
# dataset/dataset/soybean/4986.tif
# dataset/dataset/soybean/6538.tif
# dataset/dataset/soybean/493.tif
# dataset/dataset/soybean/5368.tif
# dataset/dataset/soybean/838.tif
# dataset/dataset/soybean/6998.tif
# dataset/dataset/soybean/6943.tif
# dataset/dataset/soybean/4718.tif
# dataset/dataset/soybean/4241.tif
# dataset/dataset/soybean/5235.tif
# dataset/dataset/soybean/6261.tif
# dataset/dataset/soybean/2317.tif
# dataset/dataset/soybean/5047.tif
# dataset/dataset/soybean/1668.tif
# dataset/dataset/soybean/7288.tif
# dataset/dataset/soybean/4759.tif
# dataset/dataset/soybean/6086.tif
# dataset/dataset/soybean/2306.tif
# dataset/dataset/soybean/832.tif
# dataset/dataset/soybean/1543.tif
# dataset/dataset/soybean/4647.tif
# dataset/dataset/soybean/6592.tif
# dataset/dataset/soybean/877.tif
# dataset/dataset/soybean/2866.tif
# dataset/dataset/soybean/1484.tif
# dataset/dataset/soybean/3723.tif
# dataset/dataset/soybean/349.tif
# dataset/dataset/soybean/7318.tif
# dataset/dataset/soybean/3086.tif
# dataset/dataset/soybean/5130.tif
# dataset/dataset/soybean/7003.tif
# dataset/dataset/soybean/5665.tif
# dataset/dataset/soybean/1476.tif
# dataset/dataset/soybean/1732.tif
# dataset/dataset/soybean/1753.tif
# dataset/dataset/soybean/1774.tif
# dataset/dataset/soybean/6364.tif
# dataset/dataset/soybean/2577.tif
# dataset/dataset/soybean/1896.tif
# dataset/dataset/soybean/5233.tif
# dataset/dataset/soybean/2979.tif
# dataset/dataset/soybean/4023.tif
# dataset/dataset/soybean/7190.tif
# dataset/dataset/soybean/6244.tif
# dataset/dataset/soybean/5183.tif
# dataset/dataset/soybean/6137.tif
# dataset/dataset/soybean/7056.tif
# dataset/dataset/soybean/5970.tif
# dataset/dataset/soybean/6626.tif
# dataset/dataset/soybean/1569.tif
# dataset/dataset/soybean/6048.tif
# dataset/dataset/soybean/2508.tif
# dataset/dataset/soybean/5877.tif
# dataset/dataset/soybean/2546.tif
# dataset/dataset/soybean/4717.tif
# dataset/dataset/soybean/3492.tif
# dataset/dataset/soybean/6.tif
# dataset/dataset/soybean/5029.tif
# dataset/dataset/soybean/2089.tif
# dataset/dataset/soybean/5869.tif
# dataset/dataset/soybean/1637.tif
# dataset/dataset/soybean/2227.tif
# dataset/dataset/soybean/415.tif
# dataset/dataset/soybean/2189.tif
# dataset/dataset/soybean/6113.tif
# dataset/dataset/soybean/126.tif
# dataset/dataset/soybean/5737.tif
# dataset/dataset/soybean/6189.tif
# dataset/dataset/soybean/1687.tif
# dataset/dataset/soybean/3242.tif
# dataset/dataset/soybean/6641.tif
# dataset/dataset/soybean/3474.tif
# dataset/dataset/soybean/4521.tif
# dataset/dataset/soybean/1395.tif
# dataset/dataset/soybean/6304.tif
# dataset/dataset/soybean/5567.tif
# dataset/dataset/soybean/1439.tif
# dataset/dataset/soybean/1013.tif
# dataset/dataset/soybean/2197.tif
# dataset/dataset/soybean/4404.tif
# dataset/dataset/soybean/459.tif
# dataset/dataset/soybean/5338.tif
# dataset/dataset/soybean/160.tif
# dataset/dataset/soybean/3932.tif
# dataset/dataset/soybean/3631.tif
# dataset/dataset/soybean/2971.tif
# dataset/dataset/soybean/781.tif
# dataset/dataset/soybean/6692.tif
# dataset/dataset/soybean/3565.tif
# dataset/dataset/soybean/3858.tif
# dataset/dataset/soybean/2275.tif
# dataset/dataset/soybean/262.tif
# dataset/dataset/soybean/4497.tif
# dataset/dataset/soybean/1744.tif
# dataset/dataset/soybean/1423.tif
# dataset/dataset/soybean/5236.tif
# dataset/dataset/soybean/5973.tif
# dataset/dataset/soybean/696.tif
# dataset/dataset/soybean/7022.tif
# dataset/dataset/soybean/4262.tif
# dataset/dataset/soybean/5610.tif
# dataset/dataset/soybean/4495.tif
# dataset/dataset/soybean/185.tif
# dataset/dataset/soybean/7189.tif
# dataset/dataset/soybean/6718.tif
# dataset/dataset/soybean/1836.tif
# dataset/dataset/soybean/2602.tif
# dataset/dataset/soybean/5573.tif
# dataset/dataset/soybean/4195.tif
# dataset/dataset/soybean/217.tif
# dataset/dataset/soybean/3770.tif
# dataset/dataset/soybean/2334.tif
# dataset/dataset/soybean/2985.tif
# dataset/dataset/soybean/2592.tif
# dataset/dataset/soybean/3143.tif
# dataset/dataset/soybean/2384.tif
# dataset/dataset/soybean/4173.tif
# dataset/dataset/soybean/1338.tif
# dataset/dataset/soybean/1577.tif
# dataset/dataset/soybean/6061.tif
# dataset/dataset/soybean/4985.tif
# dataset/dataset/soybean/772.tif
# dataset/dataset/soybean/5113.tif
# dataset/dataset/soybean/5666.tif
# dataset/dataset/soybean/668.tif
# dataset/dataset/soybean/4979.tif
# dataset/dataset/soybean/559.tif
# dataset/dataset/soybean/4637.tif
# dataset/dataset/soybean/225.tif
# dataset/dataset/soybean/455.tif
# dataset/dataset/soybean/6220.tif
# dataset/dataset/soybean/3978.tif
# dataset/dataset/soybean/5915.tif
# dataset/dataset/soybean/1707.tif
# dataset/dataset/soybean/6410.tif
# dataset/dataset/soybean/2114.tif
# dataset/dataset/soybean/1859.tif
# dataset/dataset/soybean/3277.tif
# dataset/dataset/soybean/5342.tif
# dataset/dataset/soybean/5010.tif
# dataset/dataset/soybean/5848.tif
# dataset/dataset/soybean/2851.tif
# dataset/dataset/soybean/749.tif
# dataset/dataset/soybean/6983.tif
# dataset/dataset/soybean/458.tif
# dataset/dataset/soybean/7269.tif
# dataset/dataset/soybean/3896.tif
# dataset/dataset/soybean/7119.tif
# dataset/dataset/soybean/2259.tif
# dataset/dataset/soybean/3841.tif
# dataset/dataset/soybean/4357.tif
# dataset/dataset/soybean/98.tif
# dataset/dataset/soybean/3925.tif
# dataset/dataset/soybean/2457.tif
# dataset/dataset/soybean/653.tif
# dataset/dataset/soybean/4874.tif
# dataset/dataset/soybean/5059.tif
# dataset/dataset/soybean/2135.tif
# dataset/dataset/soybean/4594.tif
# dataset/dataset/soybean/1724.tif
# dataset/dataset/soybean/4946.tif
# dataset/dataset/soybean/866.tif
# dataset/dataset/soybean/791.tif
# dataset/dataset/soybean/3838.tif
# dataset/dataset/soybean/859.tif
# dataset/dataset/soybean/6582.tif
# dataset/dataset/soybean/5093.tif
# dataset/dataset/soybean/6808.tif
# dataset/dataset/soybean/7300.tif
# dataset/dataset/soybean/3232.tif
# dataset/dataset/soybean/1524.tif
# dataset/dataset/soybean/6725.tif
# dataset/dataset/soybean/6152.tif
# dataset/dataset/soybean/6375.tif
# dataset/dataset/soybean/7171.tif
# dataset/dataset/soybean/5546.tif
# dataset/dataset/soybean/5519.tif
# dataset/dataset/soybean/1187.tif
# dataset/dataset/soybean/3571.tif
# dataset/dataset/soybean/5720.tif
# dataset/dataset/soybean/27.tif
# dataset/dataset/soybean/6075.tif
# dataset/dataset/soybean/5931.tif
# dataset/dataset/soybean/1038.tif
# dataset/dataset/soybean/2082.tif
# dataset/dataset/soybean/1300.tif
# dataset/dataset/soybean/3307.tif
# dataset/dataset/soybean/5011.tif
# dataset/dataset/soybean/33.tif
# dataset/dataset/soybean/4305.tif
# dataset/dataset/soybean/7097.tif
# dataset/dataset/soybean/1461.tif
# dataset/dataset/soybean/5030.tif
# dataset/dataset/soybean/2298.tif
# dataset/dataset/soybean/6644.tif
# dataset/dataset/soybean/6214.tif
# dataset/dataset/soybean/6531.tif
# dataset/dataset/soybean/1055.tif
# dataset/dataset/soybean/5158.tif
# dataset/dataset/soybean/5584.tif
# dataset/dataset/soybean/5826.tif
# dataset/dataset/soybean/2630.tif
# dataset/dataset/soybean/2201.tif
# dataset/dataset/soybean/5555.tif
# dataset/dataset/soybean/1361.tif
# dataset/dataset/soybean/635.tif
# dataset/dataset/soybean/2998.tif
# dataset/dataset/soybean/3224.tif
# dataset/dataset/soybean/561.tif
# dataset/dataset/soybean/4677.tif
# dataset/dataset/soybean/108.tif
# dataset/dataset/soybean/1731.tif
# dataset/dataset/soybean/6112.tif
# dataset/dataset/soybean/4415.tif
# dataset/dataset/soybean/1254.tif
# dataset/dataset/soybean/2368.tif
# dataset/dataset/soybean/3430.tif
# dataset/dataset/soybean/5058.tif
# dataset/dataset/soybean/6142.tif
# dataset/dataset/soybean/3655.tif
# dataset/dataset/soybean/4598.tif
# dataset/dataset/soybean/4451.tif
# dataset/dataset/soybean/5619.tif
# dataset/dataset/soybean/919.tif
# dataset/dataset/soybean/6940.tif
# dataset/dataset/soybean/4000.tif
# dataset/dataset/soybean/4508.tif
# dataset/dataset/soybean/3888.tif
# dataset/dataset/soybean/3501.tif
# dataset/dataset/soybean/3399.tif
# dataset/dataset/soybean/2240.tif
# dataset/dataset/soybean/7047.tif
# dataset/dataset/soybean/5779.tif
# dataset/dataset/soybean/586.tif
# dataset/dataset/soybean/2633.tif
# dataset/dataset/soybean/6546.tif
# dataset/dataset/soybean/4943.tif
# dataset/dataset/soybean/2960.tif
# dataset/dataset/soybean/879.tif
# dataset/dataset/soybean/1123.tif
# dataset/dataset/soybean/4544.tif
# dataset/dataset/soybean/4528.tif
# dataset/dataset/soybean/1825.tif
# dataset/dataset/soybean/5602.tif
# dataset/dataset/soybean/4295.tif
# dataset/dataset/soybean/1538.tif
# dataset/dataset/soybean/4105.tif
# dataset/dataset/soybean/1449.tif
# dataset/dataset/soybean/6830.tif
# dataset/dataset/soybean/3239.tif
# dataset/dataset/soybean/4623.tif
# dataset/dataset/soybean/2475.tif
# dataset/dataset/soybean/7147.tif
# dataset/dataset/soybean/4813.tif
# dataset/dataset/soybean/2154.tif
# dataset/dataset/soybean/2342.tif
# dataset/dataset/soybean/6003.tif
# dataset/dataset/soybean/6219.tif
# dataset/dataset/soybean/1752.tif
# dataset/dataset/soybean/1987.tif
# dataset/dataset/soybean/4584.tif
# dataset/dataset/soybean/4438.tif
# dataset/dataset/soybean/6817.tif
# dataset/dataset/soybean/3603.tif
# dataset/dataset/soybean/6707.tif
# dataset/dataset/soybean/1938.tif
# dataset/dataset/soybean/783.tif
# dataset/dataset/soybean/2338.tif

# %%
os.chdir('/content/')

classes = ['broadleaf', 'grass', 'soil', 'soybean'] 
data_dir = r'./dataset/dataset/'
directory = data_dir

# %%
pathname = os.path.join(directory,classes[0])
broadleaf = os.listdir(pathname)
pathname = os.path.join(directory,classes[1])
grass = os.listdir(pathname)
pathname = os.path.join(directory,classes[2])
soil = os.listdir(pathname)
pathname = os.path.join(directory,classes[3])
soybean = os.listdir(pathname)

# %%
# Number of images in the directories
print(classes[0] , str(len(broadleaf)))
print(classes[1] , str(len(grass)))
print(classes[2] , str(len(soil)))
print(classes[3] , str(len(soybean)))
# Out:
# broadleaf 1191
# grass 3520
# soil 3249
# soybean 7376

# %%
def show_image(filename):
  image = plt.imread(filename,format='tif')
  fig, ax = plt.subplots()
  im = ax.imshow(image)
  plt.show()
  print(image.shape)

# %%
filename = os.path.join(os.path.join(directory,classes[0]),broadleaf[random.randint(0,len(broadleaf))])
show_image(filename)
# Out:
# (272, 291, 3)

# %%
filename = os.path.join(os.path.join(directory,classes[1]),grass[random.randint(0,len(grass))])
show_image(filename)
# Out:
# (216, 254, 3)

# %%
filename = os.path.join(os.path.join(directory,classes[2]),soil[random.randint(0,len(soil))])
show_image(filename)
# Out:
# (143, 287, 3)

# %%
filename = os.path.join(os.path.join(directory,classes[3]),soybean[random.randint(0,len(soybean))])
show_image(filename)
# Out:
# (251, 255, 3)

# %%
num2class = {0: 'broadleaf', 
         1: 'grass', 
         2: 'soil', 
         3: 'soybean'}

class2num = {'broadleaf' : 0, 
         'grass' : 1, 
         'soil' : 2, 
         'soybean' : 3}

# %%
m = 1
num_file = 1100 * m
num_train = 1000 * m  
num_val = 50 * m
num_test = 50 * m

all_files = [] 
num_data =num_file*len(classes)
Y = np.zeros(num_data)


for i, cls in enumerate(classes):
    all_files += [f for f in glob.glob(data_dir+cls+'/*.tif')][:num_file]
    Y[i*num_file:(i+1)*num_file] = i # label all classes with int [0.. len(classes)]

# %%
# Image dimension
im_width = 200
im_height = 200 
im_channel = 3
dim = im_width * im_height * im_channel

X = np.ndarray(shape=(num_data, im_width, im_height, im_channel), dtype=np.float64)

for idx, file in enumerate(all_files):
    X[idx] = cv2.resize(cv2.imread(file), (im_width, im_height))

X_train = np.empty(shape=(num_train*len(classes),im_width, im_height, im_channel), dtype=np.float64)
X_val = np.empty(shape=(num_val*len(classes),im_width, im_height, im_channel), dtype=np.float64)
X_test = np.empty(shape=(num_test*len(classes),im_width, im_height, im_channel), dtype=np.float64)

y_train = np.empty(num_train*len(classes))
y_val = np.empty(num_val*len(classes))
y_test = np.empty(num_test*len(classes)) 

for i, cls in enumerate(classes): 
    X_test[num_test*i:num_test*(i+1)] = X[np.where(Y == i)[0][:num_test]]
    X_val[num_val*i:num_val*(i+1)] = X[np.where(Y == i)[0][num_test:num_test+num_val]]
    X_train[num_train*i:num_train*(i+1)] = X[np.where(Y == i)[0][num_test+num_val:]]
    
    y_test[num_test*i:num_test*(i+1)] = i
    y_val[num_val*i:num_val*(i+1)] = i
    y_train[num_train*i:num_train*(i+1)] = i

del Y 
del X

# %%
X_train.shape
# Out:
# (4000, 200, 200, 3)

# %%
# Extract features 
#Shuffle training index
train_idxs = np.random.permutation(X_train.shape[0])
y_train  = y_train[train_idxs].astype(int)
X_train = X_train[train_idxs]

X_train = np.reshape(X_train, (X_train.shape[0], -1)).astype('float64')
X_test = np.reshape(X_test, (X_test.shape[0], -1)).astype('float64')
X_val = np.reshape(X_val, (X_val.shape[0], -1)).astype('float64')

X_tiny = X_train[100:110].astype('float64')
y_tiny = y_train[100:110].astype(int)
num_dev = 500

X_dev = X_train[0:num_dev].astype('float64')
y_dev = y_train[0:num_dev].astype(int)
print("X_train shape", X_train.shape, "| y_train shape:", y_train.shape)
print("X_test shape", X_test.shape, "| y_test shape:", y_test.shape)
print("X_val shape", X_val.shape, "| y_val shape:", y_val.shape)
print("X_dev shape", X_dev.shape, "| y_dev shape:", y_dev.shape)
print("X_tiny shape", X_tiny.shape, "| y_tiny shape:", y_tiny.shape)

#Subtract out the mean image 
#first: compute the mean image this will be used to "normalize" img data
mean_image = np.mean(X_train, axis=0) #axis=0. stack horizontally

X_train -= mean_image
X_val -= mean_image 
X_test -= mean_image
X_dev -= mean_image
X_tiny -= mean_image


print('=====STACK BIAS term=====')
print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
print("X_val shape", X_val.shape)
print("X_dev shape", X_dev.shape)
print("X_tiny shape", X_tiny.shape)
# Out:
# X_train shape (4000, 120000) | y_train shape: (4000,)
# X_test shape (200, 120000) | y_test shape: (200,)
# X_val shape (200, 120000) | y_val shape: (200,)
# X_dev shape (500, 120000) | y_dev shape: (500,)
# X_tiny shape (10, 120000) | y_tiny shape: (10,)
# =====STACK BIAS term=====
# X_train shape (4000, 120000)
# X_test shape (200, 120000)
# X_val shape (200, 120000)
# X_dev shape (500, 120000)
# X_tiny shape (10, 120000)

# %%
# Visualize some images 
# Make sure that everything when OK
classes = ['broadleaf', 'grass', 'soil', 'soybean']
n_class = len(classes)
samples_per_class = 4

# %%
# show some train images
for y, cls in enumerate(classes):
    idxes = np.flatnonzero(y == y_train)
    idxes = np.random.choice(idxes, samples_per_class, replace = False)
    for i, idx in enumerate(idxes):
        plt_idx = i * n_class + y + 1
        plt.subplot(samples_per_class,n_class, plt_idx)
        plt.imshow(X_train[idx].reshape(im_width, im_height, im_channel).astype('uint8'))
        if(i==0): plt.title(cls)

plt.show()

# %%
class TwoLayerNet():
    def __init__(self, input_size, hidden_size, output_size, std= 1e-4):
        '''
        std: weight initialization term
        W1: first layer weight, shape(D x H) 
        W2: second layer weight shape(H x C) 
        C: num_classes(output_size) , H: hidden_size, D: data_dim(input_size) 
        '''
        self.params = {}
        self.params['W1'] = std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)
        
    def loss(self, X, y = None, reg=0.0):
        '''
        reg: regularization strength
        X: ndarray shape(N x C). N: num of data 
        y: vector of training label
        '''
        #DEfine relu activation function 
        relu = lambda x:np.maximum(0,x)

        #unpack
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D = X.shape

        #Forward prop
        layer1 = relu(X.dot(W1) + b1)  #(N,D) x (D,H) = (N,H)
        scores = layer1.dot(W2) + b2

        #if target is not given then jump out 
        if(y is None): 
            return scores

        #compute the loss 
        ##Normalization trick to prevent overflow when compute exp 
        scores -= scores.max()#stack vertically

        scores = np.exp(scores)
        scores_sumexp = np.sum(scores, axis=1)#stack vertically

        ##Nomalize all score 
        softmax = scores / scores_sumexp.reshape(N,1)  #Shape: (N, C)
        #total loss of all training. -log of all correct score
        loss =  (-1.0) * np.sum(np.log(softmax[range(N),y]))

        ##Normalize the loss and add regularization strength 
        loss /= N 
        loss += reg * np.sum(W1 * W1) 
        loss += reg * np.sum(W2 * W2) 

        #Backward pass on the net 
        grads = {}

        correct_class_scores = scores[range(N), y]
        softmax[range(N), y] = (-1.0) * (scores_sumexp - correct_class_scores)/scores_sumexp
        softmax /= N


        #Want to find dW2(dL/dW2)
        # Derivation: dL/dW2 = dL/dscore * dscore/dW2(chain rule)
        #dL/dscore = softmax since L(score) = softmax(variable)
        #dscore/dW2 = relu_(hidden layer output)
        grads['W2'] = layer1.T.dot(softmax)
        grads['b2'] = np.sum(softmax, axis=0)#stack horizontally
        grads['W2'] += reg * 2 * W2

        #dL/dW1 = dL/dscore * dscore/drelu(layler1) * drelu(layer1)/dW1 
        #dL/dW1 = dW1 = softmax * W2 * X 
        hidden = softmax.dot(W2.T)

        #derivative of a max gate
        #Intuition: in forward pass if neuron didn't fire that mean. the derivative of that neuron 
        # is 0. This might be bad since this will kill gradient. 
        hidden[layer1 == 0] = 0 

        grads['W1'] = X.T.dot(hidden) 
        grads['b1'] = np.sum(hidden, axis=0) #stack horizontally 
        grads['W1'] += reg * 2 * W1

        return loss, grads

    def train(self, X, y, X_val, y_val, 
              learning_rate =1e-3, learning_rate_decay=0.95, 
              reg=5e-6, num_iters=100, 
              batch_size=200, it_verbose = 1, verbose=False):
        '''
        Train using SGD 
        Input: 
            X: nd array shape(N x D) 
            y: vector of train label 
            X_val: nd array shape( n_VAL , D) Use as validation set after each epoch 
            y_val: vector of validation label 
        '''
        N, D = X.shape
        N_val = X_val.shape[0]
        iteration_per_epoch = max(N/batch_size, 1)
        
        loss_hist = []
        train_acc_hist = []
        val_acc_hist = []
        
        for it in range(num_iters):
            sampling = np.random.choice(np.arange(N), batch_size, replace=False) 
            X_batch = X[sampling]
            y_batch = y[sampling]
            
            #compute loss and gradients
            loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
            loss_hist.append(loss) 
            
            #Update rule 
            self.params['W1'] += (-1.0) * learning_rate * grads['W1']
            self.params['b1'] += (-1.0) * learning_rate * grads['b1']
            self.params['W2'] += (-1.0) * learning_rate * grads['W2']
            self.params['b2'] += (-1.0) * learning_rate * grads['b2']
            
            if(verbose and it%it_verbose==0):
                print('iteration: %d / %d | Loss: %f' % (it, num_iters, loss)) 
            # Every epoch, check train and val accuracy and decay learning rate.
            if (it % iteration_per_epoch == 0):
                # Check accuracy
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_hist.append(train_acc)
                val_acc_hist.append(val_acc)

                # Decay learning rate
                learning_rate *= learning_rate_decay
        return {
            'loss_hist':loss_hist,
            'train_acc_hist':train_acc_hist,
            'val_acc_hist':val_acc_hist
        }

    def predict(self, X):
        """
        Use the trained weights of this two-layer network to predict labels for
        data points. For each data point we predict scores for each of the C
        classes, and assign each data point to the class with the highest score.

        Inputs:
        - X: A numpy array of shape (N, D) giving N D-dimensional data points to
        classify.

        Returns:
        - y_pred: A numpy array of shape (N,) giving predicted labels for each of
        the elements of X. For all i, y_pred[i] = c means that X[i] is predicted
        to have class c, where 0 <= c < C.
        """
        y_pred = None
        relu = lambda x:np.maximum(0,x)
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']

        #Forward propagation though the network 
        layer1 = relu(X.dot(W1) + b1)
        scores = layer1.dot(W2) + b2 #shape: (N x C)
        y_pred = np.argmax(scores, axis=1)

        return y_pred

# %%
input_size = im_width * im_height * im_channel
hidden_size = 200
output_size = n_class 
std = 1e-3 # size initialization parameter

net = TwoLayerNet(input_size, hidden_size,output_size,std )
#stats = net.train(X_dev, y_dev, X_val, y_val, 
#              learning_rate =1e-5, learning_rate_decay=0.95, 
#              reg=0.0, num_iters=140, 
#              batch_size=100, it_verbose = 10,verbose=True)
stats = net.train(X_train, y_train, X_val, y_val, 
              learning_rate =1e-5, learning_rate_decay=0.95, 
              reg=0.0, num_iters=500, 
              batch_size=128, it_verbose = 10,verbose=True)
# Out:
# iteration: 0 / 500 | Loss: 1.376965
# iteration: 10 / 500 | Loss: 1.357561
# iteration: 20 / 500 | Loss: 1.311567
# iteration: 30 / 500 | Loss: 1.290783
# iteration: 40 / 500 | Loss: 1.244110
# iteration: 50 / 500 | Loss: 1.209794
# iteration: 60 / 500 | Loss: 1.213838
# iteration: 70 / 500 | Loss: 1.171750
# iteration: 80 / 500 | Loss: 1.111610
# iteration: 90 / 500 | Loss: 1.077429
# iteration: 100 / 500 | Loss: 1.086677
# iteration: 110 / 500 | Loss: 1.077580
# iteration: 120 / 500 | Loss: 0.918258
# iteration: 130 / 500 | Loss: 0.984695
# iteration: 140 / 500 | Loss: 0.943904
# iteration: 150 / 500 | Loss: 0.989477
# iteration: 160 / 500 | Loss: 0.890310
# iteration: 170 / 500 | Loss: 0.905110
# iteration: 180 / 500 | Loss: 0.954160
# iteration: 190 / 500 | Loss: 0.842447
# iteration: 200 / 500 | Loss: 0.823423
# iteration: 210 / 500 | Loss: 0.859655
# iteration: 220 / 500 | Loss: 0.794277
# iteration: 230 / 500 | Loss: 0.804519
# iteration: 240 / 500 | Loss: 0.743502
# iteration: 250 / 500 | Loss: 0.803630
# iteration: 260 / 500 | Loss: 0.766503
# iteration: 270 / 500 | Loss: 0.789092
# iteration: 280 / 500 | Loss: 0.757082
# iteration: 290 / 500 | Loss: 0.800229
# iteration: 300 / 500 | Loss: 0.846323
# iteration: 310 / 500 | Loss: 0.712001
# iteration: 320 / 500 | Loss: 0.826250
# iteration: 330 / 500 | Loss: 0.716480
# iteration: 340 / 500 | Loss: 0.706787
# iteration: 350 / 500 | Loss: 0.765074
# iteration: 360 / 500 | Loss: 0.669381
# iteration: 370 / 500 | Loss: 0.701553
# iteration: 380 / 500 | Loss: 0.736925
# iteration: 390 / 500 | Loss: 0.663822
# iteration: 400 / 500 | Loss: 0.782605
# iteration: 410 / 500 | Loss: 0.615868
# iteration: 420 / 500 | Loss: 0.708157
# iteration: 430 / 500 | Loss: 0.739083
# iteration: 440 / 500 | Loss: 0.709004
# iteration: 450 / 500 | Loss: 0.720068
# iteration: 460 / 500 | Loss: 0.733552
# iteration: 470 / 500 | Loss: 0.601097
# iteration: 480 / 500 | Loss: 0.771075
# iteration: 490 / 500 | Loss: 0.701882

# %%
# plot loss history and train/ validation accuracies history
plt.rcParams['figure.figsize'] = (15.0, 15.0) # set default size of plots
plt.subplot(2,1,1) 
plt.plot(stats['loss_hist'])
plt.title('Loss History')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2,1,2)
plt.plot(stats['train_acc_hist'], label='train')
plt.plot(stats['val_acc_hist'], label='val')
plt.xlabel('Epoch')
plt.ylabel('Classfication Accuracies')
plt.legend()
plt.show()

# %% [markdown]
# Prediction Time

# %%
# predict a random image
def predict_random_image():
  # Choose an image
  idx = random.randint(0,len(y_dev))
  # Preprozess image
  plt.imshow((X_dev[idx]+mean_image).reshape(im_width, im_height, im_channel).astype('uint8'))
  plt.title(num2class[y_dev[idx]])
  plt.show()
  # Make the prediction
  result = net.predict(X_dev[idx].reshape(-1,X_dev[idx].shape[0]))
  print("Prediction: ", num2class[np.asscalar(result)])
 

plt.rcParams['figure.figsize'] = (11.0, 9.0) # set default size of plots

# %%
predict_random_image()
# Out:
# Prediction:  broadleaf

# %%
predict_random_image()
# Out:
# Prediction:  soybean
